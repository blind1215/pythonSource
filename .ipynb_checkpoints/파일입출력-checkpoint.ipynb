# %% [markdown]
# ## 파일 출력

# %%
f = open("data/test1.txt","w")
print(dir(f))
f.close()
# Out:
# ['_CHUNK_SIZE', '__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_checkClosed', '_checkReadable', '_checkSeekable', '_checkWritable', '_finalizing', 'buffer', 'close', 'closed', 'detach', 'encoding', 'errors', 'fileno', 'flush', 'isatty', 'line_buffering', 'mode', 'name', 'newlines', 'read', 'readable', 'readline', 'readlines', 'reconfigure', 'seek', 'seekable', 'tell', 'truncate', 'writable', 'write', 'write_through', 'writelines']

# %%
f = open("data/test1.txt","w",encoding="utf-8")
f.write("안녕하세요\n만나서 반갑습니다.")
f.close()

# %%
f = open("data/test1.txt","w",encoding="utf-8")
for i in range(1,11):
    data = "%d번째 줄입니다.\n" % i
    f.write(data)
f.close()

# %%
f = open("data/test1.txt","a",encoding="utf-8")
for i in range(1,11):
    data = "안녕하세요\n" 
    f.write(data)
f.close()

# %%
# 리스트 값 파일에 쓰기
f = open("data/test1.txt","a",encoding="utf-8")
list1 = ["kim\n","pack\n","choi\n"]
f.writelines(list1)
f.close()

# %%
with open("data/dic1.txt","w",encoding="utf-8") as f:
    dict1 = {"name":"hong","age":25,"addr":"서울"}
    for k,v in dict1.items():
        f.writelines("{}:{}\n".format(k,v))

# %%
# 1000명의 키와 몸무게를 랜덤하게 생성해 파일에 기록하기
import random

#list()=> 괄호안에 데이터들을 리스트로 생성
hanguls = list("가나다라마바사아자차카타파하")

with open("data/info.txt","w",encoding="utf-8") as f:
    for i in range(1000):
        # choice():리스트 중에서 아무 원소나 하나 추출
        name = random.choice(hanguls) + random.choice(hanguls)
        weight = random.randrange(40,100) # 범위 40~100사이에 숫자 무작위
        height = random.randrange(140,200) # 범위 140~200사이에 숫자 무작위
        f.writelines("{},{},{}\n".format(name,weight,height))

# %% [markdown]
# ## 파일 입력

# %%
f= open("data/review.txt","r",encoding="utf-8")
content = f.read()
print(content)
f.close()
# Out:
# The film, projected in the form of animation,
# imparts the lesson of how wars can be eluded through reasoning and peaceful dialogues,
# which eventually paves the path for gaining a fresh perspective on an age-old problem.
# The story also happens to centre around two parallel characters, Shundi King and Hundi King,
# who are twins, but they constantly fight over unresolved issues planted in their minds
# by external forces from within their very own units.

# %%
with open("data/review.txt","r",encoding="utf-8") as f:
    content = f.read()
    print(content)
# Out:
# The film, projected in the form of animation,
# imparts the lesson of how wars can be eluded through reasoning and peaceful dialogues,
# which eventually paves the path for gaining a fresh perspective on an age-old problem.
# The story also happens to centre around two parallel characters, Shundi King and Hundi King,
# who are twins, but they constantly fight over unresolved issues planted in their minds
# by external forces from within their very own units.

# %%
with open("data/review.txt","r",encoding="utf-8") as f:
    for c in f:
        #print(c) #엔터
        print(c.strip()) #엔터 제거
# Out:
# The film, projected in the form of animation,
# imparts the lesson of how wars can be eluded through reasoning and peaceful dialogues,
# which eventually paves the path for gaining a fresh perspective on an age-old problem.
# The story also happens to centre around two parallel characters, Shundi King and Hundi King,
# who are twins, but they constantly fight over unresolved issues planted in their minds
# by external forces from within their very own units.

# %%
with open("data/review.txt","r",encoding="utf-8") as f:
    line = f.readline() # 줄 단위로 읽어오기
    while line :
        print(line,end="")
        line = f.readline()
# Out:
# The film, projected in the form of animation,
# imparts the lesson of how wars can be eluded through reasoning and peaceful dialogues,
# which eventually paves the path for gaining a fresh perspective on an age-old problem.
# The story also happens to centre around two parallel characters, Shundi King and Hundi King,
# who are twins, but they constantly fight over unresolved issues planted in their minds
# by external forces from within their very own units.

# %%
with open("data/review.txt","r",encoding="utf-8") as f:
    print(f.readlines()) # 결과를 리스트로 돌려받기
# Out:
# ['The film, projected in the form of animation,\n', 'imparts the lesson of how wars can be eluded through reasoning and peaceful dialogues,\n', 'which eventually paves the path for gaining a fresh perspective on an age-old problem.\n', 'The story also happens to centre around two parallel characters, Shundi King and Hundi King,\n', 'who are twins, but they constantly fight over unresolved issues planted in their minds\n', 'by external forces from within their very own units.']

# %%
# 리스트 생성
score = []

with open("data/score.txt","r",encoding="utf-8") as f:
    for num in f:
        score.append(int(num))
    print(score)
    
#총점과 평균을 구한 후 출력하기
total = 0

for jumsu in score:
    total += jumsu
    
print("총점은 {}".format(total))
print("평균은 {:0.3f}".format(total/len(score)))

#선생님 방식

print("총점 :{}".format(sum(score)))
print("평균 :{:0.3f}".format(sum(score)/len(score)))
# Out:
# [95, 78, 92, 89, 100, 66]
# 총점은 520
# 평균은 86.667
# 총점 :520
# 평균 :86.667

# %%
# score.txt 를 읽어서 총점과 평균을 구해서 result.txt 파일에 쓰기

score = []

with open("data/score.txt","r",encoding="utf-8") as f:
    for num in f:
        score.append(int(num))
    print(score)
    
#총점과 평균을 구한 후 출력하기
with open("data/result.txt","w",encoding="utf-8") as f1:
    f1.write("총점 :{}\n".format(sum(score)))
    f1.write("평균 :{:0.3f}".format(sum(score)/len(score)))
# Out:
# [95, 78, 92, 89, 100, 66]

# %%
import os



content = ""
fName = ""

fName= input("파일명을 입력해 주세요")
path = "data/"+fName

if os.path.exists(path):
    with open(path,"r",encoding="utf-8") as inFp:
        content = inFp.read()
        
    oName = input("저장할 폴더와 이름을 입력하세요")
    
    with open(oName, "w", encoding="utf-8") as outFp:
        outFp.writelines(content)
else:
    print("%s 파일이 없습니다." % fName)
# Out:
# 파일명을 입력해 주세요dic1.txt
# 저장할 폴더와 이름을 입력하세요d:/exam.txt

# %%
# info.txt 파일을 읽어서 BMI 지수를 계산한 후 출력하기

# bmi = 몸무게 / (키/100)**2

# 계산값이 >=25 과체중, >=18.5 정상체중, 저체중

with open("data/info.txt","r",encoding="utf-8") as f:
    for person in f:
        name,weight,height = person.strip().split(",")
        #print(name, weight, height)
        
        bmi = int(weight)/(int(height)/100) ** 2
        
        result = ""
        if 25 <=bmi:
            result = "과체중"
        elif 18.5 <=bmi:
            result = "정상체중"
        else:
            result = "저체중"
        
        print("이름 : {}".format(name))
        print("몸무게 : {}".format(weight))
        print("키 : {}".format(height))
        print("BMI : {}".format(bmi))
        print("결과 : {}".format(result))
        print()
# Out:
# 이름 : 라카
# 몸무게 : 54
# 키 : 188
# BMI : 15.278406518786783
# 결과 : 저체중
#
# 이름 : 다바
# 몸무게 : 90
# 키 : 168
# BMI : 31.88775510204082
# 결과 : 과체중
#
# 이름 : 카파
# 몸무게 : 74
# 키 : 155
# BMI : 30.80124869927159
# 결과 : 과체중
#
# 이름 : 라파
# 몸무게 : 72
# 키 : 143
# BMI : 35.20954569905619
# 결과 : 과체중
#
# 이름 : 파파
# 몸무게 : 50
# 키 : 192
# BMI : 13.563368055555555
# 결과 : 저체중
#
# 이름 : 나마
# 몸무게 : 85
# 키 : 170
# BMI : 29.411764705882355
# 결과 : 과체중
#
# 이름 : 카타
# 몸무게 : 61
# 키 : 177
# BMI : 19.4707778735357
# 결과 : 정상체중
#
# 이름 : 카마
# 몸무게 : 94
# 키 : 166
# BMI : 34.11235302656409
# 결과 : 과체중
#
# 이름 : 나라
# 몸무게 : 64
# 키 : 155
# BMI : 26.638917793964616
# 결과 : 과체중
#
# 이름 : 아자
# 몸무게 : 95
# 키 : 179
# BMI : 29.64951156330951
# 결과 : 과체중
#
# 이름 : 차타
# 몸무게 : 67
# 키 : 190
# BMI : 18.559556786703602
# 결과 : 정상체중
#
# 이름 : 사가
# 몸무게 : 58
# 키 : 183
# BMI : 17.319119710949863
# 결과 : 저체중
#
# 이름 : 카차
# 몸무게 : 58
# 키 : 157
# BMI : 23.53036634346221
# 결과 : 정상체중
#
# 이름 : 바카
# 몸무게 : 40
# 키 : 169
# BMI : 14.00511186583103
# 결과 : 저체중
#
# 이름 : 다나
# 몸무게 : 80
# 키 : 182
# BMI : 24.151672503320853
# 결과 : 정상체중
#
# 이름 : 마파
# 몸무게 : 62
# 키 : 172
# BMI : 20.9572742022715
# 결과 : 정상체중
#
# 이름 : 자하
# 몸무게 : 51
# 키 : 172
# BMI : 17.239048134126556
# 결과 : 저체중
#
# 이름 : 라사
# 몸무게 : 72
# 키 : 183
# BMI : 21.49959688255845
# 결과 : 정상체중
#
# 이름 : 자하
# 몸무게 : 42
# 키 : 180
# BMI : 12.962962962962962
# 결과 : 저체중
#
# 이름 : 파다
# 몸무게 : 55
# 키 : 149
# BMI : 24.77365884419621
# 결과 : 정상체중
#
# 이름 : 파자
# 몸무게 : 72
# 키 : 178
# BMI : 22.724403484408533
# 결과 : 정상체중
#
# 이름 : 자자
# 몸무게 : 97
# 키 : 149
# BMI : 43.69172559794604
# 결과 : 과체중
#
# 이름 : 바나
# 몸무게 : 42
# 키 : 150
# BMI : 18.666666666666668
# 결과 : 정상체중
#
# 이름 : 가파
# 몸무게 : 75
# 키 : 151
# BMI : 32.89329415376518
# 결과 : 과체중
#
# 이름 : 타라
# 몸무게 : 50
# 키 : 150
# BMI : 22.22222222222222
# 결과 : 정상체중
#
# 이름 : 바차
# 몸무게 : 59
# 키 : 141
# BMI : 29.676575624968567
# 결과 : 과체중
#
# 이름 : 나하
# 몸무게 : 50
# 키 : 179
# BMI : 15.605006085952374
# 결과 : 저체중
#
# 이름 : 가자
# 몸무게 : 76
# 키 : 157
# BMI : 30.832893829364274
# 결과 : 과체중
#
# 이름 : 다바
# 몸무게 : 67
# 키 : 159
# BMI : 26.502116213757365
# 결과 : 과체중
#
# 이름 : 라아
# 몸무게 : 58
# 키 : 148
# BMI : 26.47918188458729
# 결과 : 과체중
#
# 이름 : 바하
# 몸무게 : 62
# 키 : 175
# BMI : 20.244897959183675
# 결과 : 정상체중
#
# 이름 : 자가
# 몸무게 : 76
# 키 : 199
# BMI : 19.191434559733338
# 결과 : 정상체중
#
# 이름 : 아하
# 몸무게 : 82
# 키 : 159
# BMI : 32.4354258138523
# 결과 : 과체중
#
# 이름 : 파파
# 몸무게 : 65
# 키 : 178
# BMI : 20.515086478979924
# 결과 : 정상체중
#
# 이름 : 라파
# 몸무게 : 94
# 키 : 163
# BMI : 35.37957770333848
# 결과 : 과체중
#
# 이름 : 다마
# 몸무게 : 96
# 키 : 142
# BMI : 47.60960126958937
# 결과 : 과체중
#
# 이름 : 하바
# 몸무게 : 53
# 키 : 171
# BMI : 18.125235115078144
# 결과 : 저체중
#
# 이름 : 라자
# 몸무게 : 94
# 키 : 143
# BMI : 45.96801799599003
# 결과 : 과체중
#
# 이름 : 카바
# 몸무게 : 71
# 키 : 174
# BMI : 23.450918219051392
# 결과 : 정상체중
#
# 이름 : 아가
# 몸무게 : 84
# 키 : 142
# BMI : 41.65840111089069
# 결과 : 과체중
#
# 이름 : 가차
# 몸무게 : 82
# 키 : 150
# BMI : 36.44444444444444
# 결과 : 과체중
#
# 이름 : 파파
# 몸무게 : 53
# 키 : 140
# BMI : 27.040816326530617
# 결과 : 과체중
#
# 이름 : 가자
# 몸무게 : 40
# 키 : 160
# BMI : 15.624999999999996
# 결과 : 저체중
#
# 이름 : 라사
# 몸무게 : 78
# 키 : 144
# BMI : 37.61574074074074
# 결과 : 과체중
#
# 이름 : 바나
# 몸무게 : 93
# 키 : 186
# BMI : 26.881720430107524
# 결과 : 과체중
#
# 이름 : 사파
# 몸무게 : 85
# 키 : 146
# BMI : 39.876149371364235
# 결과 : 과체중
#
# 이름 : 사라
# 몸무게 : 42
# 키 : 173
# BMI : 14.033211934912625
# 결과 : 저체중
#
# 이름 : 파사
# 몸무게 : 48
# 키 : 150
# BMI : 21.333333333333332
# 결과 : 정상체중
#
# 이름 : 바바
# 몸무게 : 74
# 키 : 198
# BMI : 18.875624936231
# 결과 : 정상체중
#
# 이름 : 마파
# 몸무게 : 67
# 키 : 159
# BMI : 26.502116213757365
# 결과 : 과체중
#
# 이름 : 바카
# 몸무게 : 89
# 키 : 143
# BMI : 43.52291065577779
# 결과 : 과체중
#
# 이름 : 사하
# 몸무게 : 88
# 키 : 165
# BMI : 32.323232323232325
# 결과 : 과체중
#
# 이름 : 카바
# 몸무게 : 58
# 키 : 182
# BMI : 17.509962564907617
# 결과 : 저체중
#
# 이름 : 아차
# 몸무게 : 74
# 키 : 176
# BMI : 23.889462809917354
# 결과 : 정상체중
#
# 이름 : 파마
# 몸무게 : 45
# 키 : 154
# BMI : 18.974531961544947
# 결과 : 정상체중
#
# 이름 : 사바
# 몸무게 : 48
# 키 : 167
# BMI : 17.21108680841909
# 결과 : 저체중
#
# 이름 : 마다
# 몸무게 : 71
# 키 : 153
# BMI : 30.33021487462087
# 결과 : 과체중
#
# 이름 : 다가
# 몸무게 : 85
# 키 : 179
# BMI : 26.528510346119035
# 결과 : 과체중
#
# 이름 : 사카
# 몸무게 : 63
# 키 : 163
# BMI : 23.711844630960897
# 결과 : 정상체중
#
# 이름 : 나파
# 몸무게 : 51
# 키 : 165
# BMI : 18.73278236914601
# 결과 : 정상체중
#
# 이름 : 타나
# 몸무게 : 58
# 키 : 145
# BMI : 27.586206896551722
# 결과 : 과체중
#
# 이름 : 라라
# 몸무게 : 84
# 키 : 149
# BMI : 37.83613350749966
# 결과 : 과체중
#
# 이름 : 마카
# 몸무게 : 76
# 키 : 199
# BMI : 19.191434559733338
# 결과 : 정상체중
#
# 이름 : 사타
# 몸무게 : 68
# 키 : 142
# BMI : 33.72346756595913
# 결과 : 과체중
#
# 이름 : 카자
# 몸무게 : 48
# 키 : 182
# BMI : 14.491003501992513
# 결과 : 저체중
#
# 이름 : 다가
# 몸무게 : 68
# 키 : 182
# BMI : 20.528921627822726
# 결과 : 정상체중
#
# 이름 : 파다
# 몸무게 : 86
# 키 : 199
# BMI : 21.71662331759299
# 결과 : 정상체중
#
# 이름 : 라타
# 몸무게 : 85
# 키 : 185
# BMI : 24.835646457268076
# 결과 : 정상체중
#
# 이름 : 차마
# 몸무게 : 68
# 키 : 177
# BMI : 21.705129432793896
# 결과 : 정상체중
#
# 이름 : 카파
# 몸무게 : 65
# 키 : 161
# BMI : 25.076193048107708
# 결과 : 과체중
#
# 이름 : 자라
# 몸무게 : 88
# 키 : 162
# BMI : 33.53147386069196
# 결과 : 과체중
#
# 이름 : 하자
# 몸무게 : 81
# 키 : 155
# BMI : 33.71488033298647
# 결과 : 과체중
#
# 이름 : 나차
# 몸무게 : 43
# 키 : 167
# BMI : 15.418265265875435
# 결과 : 저체중
#
# 이름 : 바나
# 몸무게 : 47
# 키 : 143
# BMI : 22.984008997995016
# 결과 : 정상체중
#
# 이름 : 타사
# 몸무게 : 69
# 키 : 177
# BMI : 22.024322512687924
# 결과 : 정상체중
#
# 이름 : 아사
# 몸무게 : 81
# 키 : 145
# BMI : 38.525564803805
# 결과 : 과체중
#
# 이름 : 마가
# 몸무게 : 92
# 키 : 142
# BMI : 45.62586788335648
# 결과 : 과체중
#
# 이름 : 하아
# 몸무게 : 40
# 키 : 199
# BMI : 10.100755031438599
# 결과 : 저체중
#
# 이름 : 다파
# 몸무게 : 52
# 키 : 185
# BMI : 15.193571950328705
# 결과 : 저체중
#
# 이름 : 차다
# 몸무게 : 87
# 키 : 157
# BMI : 35.295549515193315
# 결과 : 과체중
#
# 이름 : 파나
# 몸무게 : 93
# 키 : 143
# BMI : 45.47899652794759
# 결과 : 과체중
#
# 이름 : 타나
# 몸무게 : 99
# 키 : 196
# BMI : 25.770512286547273
# 결과 : 과체중
#
# 이름 : 나차
# 몸무게 : 50
# 키 : 188
# BMI : 14.146672702580354
# 결과 : 저체중
#
# 이름 : 아하
# 몸무게 : 59
# 키 : 170
# BMI : 20.41522491349481
# 결과 : 정상체중
#
# 이름 : 사타
# 몸무게 : 94
# 키 : 198
# BMI : 23.977145189266402
# 결과 : 정상체중
#
# 이름 : 하바
# 몸무게 : 41
# 키 : 179
# BMI : 12.796104990480947
# 결과 : 저체중
#
# 이름 : 타타
# 몸무게 : 65
# 키 : 190
# BMI : 18.005540166204987
# 결과 : 저체중
#
# 이름 : 다타
# 몸무게 : 57
# 키 : 142
# BMI : 28.268200753818686
# 결과 : 과체중
#
# 이름 : 마아
# 몸무게 : 66
# 키 : 176
# BMI : 21.306818181818183
# 결과 : 정상체중
#
# 이름 : 사바
# 몸무게 : 62
# 키 : 148
# BMI : 28.305332359386416
# 결과 : 과체중
#
# 이름 : 마바
# 몸무게 : 69
# 키 : 187
# BMI : 19.73176241814178
# 결과 : 정상체중
#
# 이름 : 파다
# 몸무게 : 80
# 키 : 160
# BMI : 31.249999999999993
# 결과 : 과체중
#
# 이름 : 사가
# 몸무게 : 66
# 키 : 164
# BMI : 24.538964901844146
# 결과 : 정상체중
#
# 이름 : 사타
# 몸무게 : 48
# 키 : 143
# BMI : 23.47303046603746
# 결과 : 정상체중
#
# 이름 : 나사
# 몸무게 : 65
# 키 : 195
# BMI : 17.094017094017094
# 결과 : 저체중
#
# 이름 : 아타
# 몸무게 : 42
# 키 : 199
# BMI : 10.60579278301053
# 결과 : 저체중
#
# 이름 : 카라
# 몸무게 : 79
# 키 : 180
# BMI : 24.382716049382715
# 결과 : 정상체중
#
# 이름 : 차파
# 몸무게 : 96
# 키 : 191
# BMI : 26.315068117650284
# 결과 : 과체중
#
# 이름 : 라하
# 몸무게 : 41
# 키 : 199
# BMI : 10.353273907224565
# 결과 : 저체중
#
# 이름 : 바하
# 몸무게 : 89
# 키 : 159
# BMI : 35.20430362722993
# 결과 : 과체중
#
# 이름 : 차다
# 몸무게 : 71
# 키 : 156
# BMI : 29.17488494411571
# 결과 : 과체중
#
# 이름 : 사마
# 몸무게 : 43
# 키 : 179
# BMI : 13.420305233919041
# 결과 : 저체중
#
# 이름 : 가타
# 몸무게 : 57
# 키 : 191
# BMI : 15.624571694854856
# 결과 : 저체중
#
# 이름 : 다카
# 몸무게 : 45
# 키 : 160
# BMI : 17.578124999999996
# 결과 : 저체중
#
# 이름 : 사마
# 몸무게 : 49
# 키 : 186
# BMI : 14.163487108336222
# 결과 : 저체중
#
# 이름 : 하차
# 몸무게 : 47
# 키 : 198
# BMI : 11.988572594633201
# 결과 : 저체중
#
# 이름 : 사아
# 몸무게 : 99
# 키 : 149
# BMI : 44.59258591955317
# 결과 : 과체중
#
# 이름 : 라다
# 몸무게 : 85
# 키 : 160
# BMI : 33.20312499999999
# 결과 : 과체중
#
# 이름 : 타라
# 몸무게 : 53
# 키 : 199
# BMI : 13.383500416656144
# 결과 : 저체중
#
# 이름 : 가차
# 몸무게 : 79
# 키 : 151
# BMI : 34.64760317529933
# 결과 : 과체중
#
# 이름 : 사타
# 몸무게 : 65
# 키 : 180
# BMI : 20.061728395061728
# 결과 : 정상체중
#
# 이름 : 나사
# 몸무게 : 43
# 키 : 146
# BMI : 20.172640270219556
# 결과 : 정상체중
#
# 이름 : 자카
# 몸무게 : 81
# 키 : 198
# BMI : 20.66115702479339
# 결과 : 정상체중
#
# 이름 : 자하
# 몸무게 : 69
# 키 : 170
# BMI : 23.87543252595156
# 결과 : 정상체중
#
# 이름 : 아하
# 몸무게 : 69
# 키 : 156
# BMI : 28.353057199211044
# 결과 : 과체중
#
# 이름 : 자아
# 몸무게 : 85
# 키 : 144
# BMI : 40.99151234567901
# 결과 : 과체중
#
# 이름 : 사아
# 몸무게 : 60
# 키 : 154
# BMI : 25.2993759487266
# 결과 : 과체중
#
# 이름 : 파사
# 몸무게 : 80
# 키 : 189
# BMI : 22.395789591556788
# 결과 : 정상체중
#
# 이름 : 라자
# 몸무게 : 87
# 키 : 184
# BMI : 25.697069943289225
# 결과 : 과체중
#
# 이름 : 나차
# 몸무게 : 80
# 키 : 167
# BMI : 28.685144680698485
# 결과 : 과체중
#
# 이름 : 바아
# 몸무게 : 74
# 키 : 166
# BMI : 26.854405574103644
# 결과 : 과체중
#
# 이름 : 하다
# 몸무게 : 97
# 키 : 192
# BMI : 26.31293402777778
# 결과 : 과체중
#
# 이름 : 사라
# 몸무게 : 45
# 키 : 158
# BMI : 18.02595737862522
# 결과 : 저체중
#
# 이름 : 차라
# 몸무게 : 45
# 키 : 140
# BMI : 22.95918367346939
# 결과 : 정상체중
#
# 이름 : 아나
# 몸무게 : 60
# 키 : 154
# BMI : 25.2993759487266
# 결과 : 과체중
#
# 이름 : 라바
# 몸무게 : 78
# 키 : 199
# BMI : 19.696472311305268
# 결과 : 정상체중
#
# 이름 : 차하
# 몸무게 : 95
# 키 : 187
# BMI : 27.166919271354622
# 결과 : 과체중
#
# 이름 : 파자
# 몸무게 : 71
# 키 : 140
# BMI : 36.22448979591837
# 결과 : 과체중
#
# 이름 : 라자
# 몸무게 : 83
# 키 : 180
# BMI : 25.61728395061728
# 결과 : 과체중
#
# 이름 : 아차
# 몸무게 : 59
# 키 : 177
# BMI : 18.832391713747644
# 결과 : 정상체중
#
# 이름 : 다나
# 몸무게 : 83
# 키 : 192
# BMI : 22.51519097222222
# 결과 : 정상체중
#
# 이름 : 라파
# 몸무게 : 47
# 키 : 143
# BMI : 22.984008997995016
# 결과 : 정상체중
#
# 이름 : 나하
# 몸무게 : 82
# 키 : 193
# BMI : 22.014013799028163
# 결과 : 정상체중
#
# 이름 : 라아
# 몸무게 : 66
# 키 : 174
# BMI : 21.79944510503369
# 결과 : 정상체중
#
# 이름 : 하타
# 몸무게 : 54
# 키 : 156
# BMI : 22.189349112426033
# 결과 : 정상체중
#
# 이름 : 카카
# 몸무게 : 48
# 키 : 168
# BMI : 17.006802721088437
# 결과 : 저체중
#
# 이름 : 아다
# 몸무게 : 90
# 키 : 160
# BMI : 35.15624999999999
# 결과 : 과체중
#
# 이름 : 나파
# 몸무게 : 87
# 키 : 163
# BMI : 32.74492829989838
# 결과 : 과체중
#
# 이름 : 타하
# 몸무게 : 56
# 키 : 177
# BMI : 17.87481247406556
# 결과 : 저체중
#
# 이름 : 자카
# 몸무게 : 56
# 키 : 176
# BMI : 18.078512396694215
# 결과 : 저체중
#
# 이름 : 나카
# 몸무게 : 77
# 키 : 194
# BMI : 20.45913487086832
# 결과 : 정상체중
#
# 이름 : 카라
# 몸무게 : 93
# 키 : 153
# BMI : 39.728309624503396
# 결과 : 과체중
#
# 이름 : 가나
# 몸무게 : 59
# 키 : 157
# BMI : 23.93606231490121
# 결과 : 정상체중
#
# 이름 : 바차
# 몸무게 : 67
# 키 : 157
# BMI : 27.18163008641324
# 결과 : 과체중
#
# 이름 : 바바
# 몸무게 : 85
# 키 : 191
# BMI : 23.299799895836188
# 결과 : 정상체중
#
# 이름 : 타자
# 몸무게 : 72
# 키 : 156
# BMI : 29.585798816568044
# 결과 : 과체중
#
# 이름 : 라가
# 몸무게 : 78
# 키 : 198
# BMI : 19.89592898683808
# 결과 : 정상체중
#
# 이름 : 다가
# 몸무게 : 71
# 키 : 196
# BMI : 18.481882548937943
# 결과 : 저체중
#
# 이름 : 라하
# 몸무게 : 43
# 키 : 171
# BMI : 14.705379432987929
# 결과 : 저체중
#
# 이름 : 차나
# 몸무게 : 44
# 키 : 159
# BMI : 17.404374826945133
# 결과 : 저체중
#
# 이름 : 다자
# 몸무게 : 58
# 키 : 148
# BMI : 26.47918188458729
# 결과 : 과체중
#
# 이름 : 바자
# 몸무게 : 56
# 키 : 146
# BMI : 26.27134546819291
# 결과 : 과체중
#
# 이름 : 가사
# 몸무게 : 43
# 키 : 153
# BMI : 18.369003374770386
# 결과 : 저체중
#
# 이름 : 사나
# 몸무게 : 59
# 키 : 147
# BMI : 27.303438382155587
# 결과 : 과체중
#
# 이름 : 가차
# 몸무게 : 65
# 키 : 145
# BMI : 30.915576694411413
# 결과 : 과체중
#
# 이름 : 나라
# 몸무게 : 90
# 키 : 153
# BMI : 38.446751249519416
# 결과 : 과체중
#
# 이름 : 바가
# 몸무게 : 43
# 키 : 154
# BMI : 18.13121942992073
# 결과 : 저체중
#
# 이름 : 아마
# 몸무게 : 68
# 키 : 180
# BMI : 20.98765432098765
# 결과 : 정상체중
#
# 이름 : 자가
# 몸무게 : 97
# 키 : 177
# BMI : 30.961728749720702
# 결과 : 과체중
#
# 이름 : 타라
# 몸무게 : 89
# 키 : 180
# BMI : 27.469135802469133
# 결과 : 과체중
#
# 이름 : 카하
# 몸무게 : 95
# 키 : 194
# BMI : 25.241789775746625
# 결과 : 과체중
#
# 이름 : 나파
# 몸무게 : 52
# 키 : 179
# BMI : 16.22920632939047
# 결과 : 저체중
#
# 이름 : 사카
# 몸무게 : 95
# 키 : 168
# BMI : 33.6592970521542
# 결과 : 과체중
#
# 이름 : 카파
# 몸무게 : 89
# 키 : 193
# BMI : 23.893258879433006
# 결과 : 정상체중
#
# 이름 : 다파
# 몸무게 : 95
# 키 : 151
# BMI : 41.6648392614359
# 결과 : 과체중
#
# 이름 : 차다
# 몸무게 : 44
# 키 : 158
# BMI : 17.625380547989103
# 결과 : 저체중
#
# 이름 : 타사
# 몸무게 : 63
# 키 : 183
# BMI : 18.812147272238644
# 결과 : 정상체중
#
# 이름 : 타마
# 몸무게 : 53
# 키 : 149
# BMI : 23.872798522589072
# 결과 : 정상체중
#
# 이름 : 카사
# 몸무게 : 74
# 키 : 146
# BMI : 34.71570651154063
# 결과 : 과체중
#
# 이름 : 하하
# 몸무게 : 64
# 키 : 182
# BMI : 19.32133800265668
# 결과 : 정상체중
#
# 이름 : 바카
# 몸무게 : 56
# 키 : 190
# BMI : 15.51246537396122
# 결과 : 저체중
#
# 이름 : 라카
# 몸무게 : 47
# 키 : 167
# BMI : 16.85252249991036
# 결과 : 저체중
#
# 이름 : 자다
# 몸무게 : 70
# 키 : 192
# BMI : 18.98871527777778
# 결과 : 정상체중
#
# 이름 : 마하
# 몸무게 : 41
# 키 : 187
# BMI : 11.724670422374102
# 결과 : 저체중
#
# 이름 : 마사
# 몸무게 : 57
# 키 : 162
# BMI : 21.719250114311837
# 결과 : 정상체중
#
# 이름 : 가파
# 몸무게 : 78
# 키 : 145
# BMI : 37.098692033293695
# 결과 : 과체중
#
# 이름 : 자마
# 몸무게 : 85
# 키 : 144
# BMI : 40.99151234567901
# 결과 : 과체중
#
# 이름 : 사차
# 몸무게 : 59
# 키 : 198
# BMI : 15.049484746454445
# 결과 : 저체중
#
# 이름 : 파마
# 몸무게 : 55
# 키 : 154
# BMI : 23.19109461966605
# 결과 : 정상체중
#
# 이름 : 가타
# 몸무게 : 65
# 키 : 145
# BMI : 30.915576694411413
# 결과 : 과체중
#
# 이름 : 라하
# 몸무게 : 79
# 키 : 161
# BMI : 30.477219243084754
# 결과 : 과체중
#
# 이름 : 바자
# 몸무게 : 43
# 키 : 146
# BMI : 20.172640270219556
# 결과 : 정상체중
#
# 이름 : 아파
# 몸무게 : 54
# 키 : 168
# BMI : 19.13265306122449
# 결과 : 정상체중
#
# 이름 : 나타
# 몸무게 : 91
# 키 : 151
# BMI : 39.91053023990176
# 결과 : 과체중
#
# 이름 : 바마
# 몸무게 : 93
# 키 : 160
# BMI : 36.32812499999999
# 결과 : 과체중
#
# 이름 : 카라
# 몸무게 : 90
# 키 : 163
# BMI : 33.87406375851557
# 결과 : 과체중
#
# 이름 : 카나
# 몸무게 : 83
# 키 : 180
# BMI : 25.61728395061728
# 결과 : 과체중
#
# 이름 : 아나
# 몸무게 : 97
# 키 : 146
# BMI : 45.50572340026272
# 결과 : 과체중
#
# 이름 : 라파
# 몸무게 : 51
# 키 : 151
# BMI : 22.367440024560327
# 결과 : 정상체중
#
# 이름 : 마아
# 몸무게 : 79
# 키 : 153
# BMI : 33.74770387457816
# 결과 : 과체중
#
# 이름 : 마바
# 몸무게 : 73
# 키 : 151
# BMI : 32.01613964299811
# 결과 : 과체중
#
# 이름 : 가하
# 몸무게 : 79
# 키 : 169
# BMI : 27.660095935016283
# 결과 : 과체중
#
# 이름 : 가가
# 몸무게 : 64
# 키 : 178
# BMI : 20.199469763918696
# 결과 : 정상체중
#
# 이름 : 바라
# 몸무게 : 53
# 키 : 187
# BMI : 15.156281277703107
# 결과 : 저체중
#
# 이름 : 사파
# 몸무게 : 99
# 키 : 177
# BMI : 31.600114909508758
# 결과 : 과체중
#
# 이름 : 바마
# 몸무게 : 64
# 키 : 154
# BMI : 26.986001011975038
# 결과 : 과체중
#
# 이름 : 하사
# 몸무게 : 77
# 키 : 140
# BMI : 39.28571428571429
# 결과 : 과체중
#
# 이름 : 자가
# 몸무게 : 70
# 키 : 157
# BMI : 28.398718000730252
# 결과 : 과체중
#
# 이름 : 가나
# 몸무게 : 74
# 키 : 181
# BMI : 22.587833094227893
# 결과 : 정상체중
#
# 이름 : 타사
# 몸무게 : 96
# 키 : 186
# BMI : 27.748872702046476
# 결과 : 과체중
#
# 이름 : 타나
# 몸무게 : 76
# 키 : 196
# BMI : 19.78342357351104
# 결과 : 정상체중
#
# 이름 : 가카
# 몸무게 : 40
# 키 : 179
# BMI : 12.484004868761899
# 결과 : 저체중
#
# 이름 : 가차
# 몸무게 : 98
# 키 : 147
# BMI : 45.3514739229025
# 결과 : 과체중
#
# 이름 : 자가
# 몸무게 : 80
# 키 : 184
# BMI : 23.629489603024574
# 결과 : 정상체중
#
# 이름 : 가아
# 몸무게 : 72
# 키 : 186
# BMI : 20.811654526534856
# 결과 : 정상체중
#
# 이름 : 마라
# 몸무게 : 77
# 키 : 142
# BMI : 38.18686768498314
# 결과 : 과체중
#
# 이름 : 가나
# 몸무게 : 92
# 키 : 175
# BMI : 30.040816326530614
# 결과 : 과체중
#
# 이름 : 아라
# 몸무게 : 72
# 키 : 186
# BMI : 20.811654526534856
# 결과 : 정상체중
#
# 이름 : 라마
# 몸무게 : 45
# 키 : 160
# BMI : 17.578124999999996
# 결과 : 저체중
#
# 이름 : 바다
# 몸무게 : 66
# 키 : 184
# BMI : 19.494328922495274
# 결과 : 정상체중
#
# 이름 : 라차
# 몸무게 : 53
# 키 : 176
# BMI : 17.110020661157026
# 결과 : 저체중
#
# 이름 : 마마
# 몸무게 : 68
# 키 : 156
# BMI : 27.94214332675871
# 결과 : 과체중
#
# 이름 : 바마
# 몸무게 : 97
# 키 : 140
# BMI : 49.489795918367356
# 결과 : 과체중
#
# 이름 : 자자
# 몸무게 : 46
# 키 : 174
# BMI : 15.193552648962875
# 결과 : 저체중
#
# 이름 : 바자
# 몸무게 : 53
# 키 : 155
# BMI : 22.060353798126947
# 결과 : 정상체중
#
# 이름 : 나아
# 몸무게 : 93
# 키 : 185
# BMI : 27.173119065010955
# 결과 : 과체중
#
# 이름 : 자타
# 몸무게 : 44
# 키 : 194
# BMI : 11.690934211924754
# 결과 : 저체중
#
# 이름 : 사차
# 몸무게 : 85
# 키 : 168
# BMI : 30.116213151927443
# 결과 : 과체중
#
# 이름 : 사자
# 몸무게 : 66
# 키 : 148
# BMI : 30.131482834185537
# 결과 : 과체중
#
# 이름 : 사마
# 몸무게 : 65
# 키 : 149
# BMI : 29.27796045223188
# 결과 : 과체중
#
# 이름 : 자카
# 몸무게 : 99
# 키 : 142
# BMI : 49.097401309264036
# 결과 : 과체중
#
# 이름 : 타하
# 몸무게 : 40
# 키 : 192
# BMI : 10.850694444444445
# 결과 : 저체중
#
# 이름 : 파마
# 몸무게 : 84
# 키 : 144
# BMI : 40.50925925925926
# 결과 : 과체중
#
# 이름 : 다카
# 몸무게 : 55
# 키 : 158
# BMI : 22.031725684986377
# 결과 : 정상체중
#
# 이름 : 카다
# 몸무게 : 51
# 키 : 154
# BMI : 21.504469556417607
# 결과 : 정상체중
#
# 이름 : 자나
# 몸무게 : 92
# 키 : 198
# BMI : 23.46699316396286
# 결과 : 정상체중
#
# 이름 : 파자
# 몸무게 : 92
# 키 : 142
# BMI : 45.62586788335648
# 결과 : 과체중
#
# 이름 : 차라
# 몸무게 : 86
# 키 : 194
# BMI : 22.85046232330747
# 결과 : 정상체중
#
# 이름 : 라하
# 몸무게 : 88
# 키 : 178
# BMI : 27.77427092538821
# 결과 : 과체중
#
# 이름 : 마다
# 몸무게 : 51
# 키 : 147
# BMI : 23.601277245592115
# 결과 : 정상체중
#
# 이름 : 카아
# 몸무게 : 68
# 키 : 162
# BMI : 25.910684346898332
# 결과 : 과체중
#
# 이름 : 사가
# 몸무게 : 46
# 키 : 149
# BMI : 20.7197873969641
# 결과 : 정상체중
#
# 이름 : 가타
# 몸무게 : 89
# 키 : 182
# BMI : 26.86873565994445
# 결과 : 과체중
#
# 이름 : 사라
# 몸무게 : 55
# 키 : 197
# BMI : 14.171970419232652
# 결과 : 저체중
#
# 이름 : 하나
# 몸무게 : 82
# 키 : 176
# BMI : 26.47210743801653
# 결과 : 과체중
#
# 이름 : 자하
# 몸무게 : 52
# 키 : 183
# BMI : 15.527486637403324
# 결과 : 저체중
#
# 이름 : 가타
# 몸무게 : 82
# 키 : 153
# BMI : 35.02926224956214
# 결과 : 과체중
#
# 이름 : 하라
# 몸무게 : 77
# 키 : 176
# BMI : 24.857954545454547
# 결과 : 정상체중
#
# 이름 : 사라
# 몸무게 : 42
# 키 : 147
# BMI : 19.436345966958214
# 결과 : 정상체중
#
# 이름 : 타아
# 몸무게 : 44
# 키 : 146
# BMI : 20.64177143929443
# 결과 : 정상체중
#
# 이름 : 가다
# 몸무게 : 60
# 키 : 193
# BMI : 16.107814974898655
# 결과 : 저체중
#
# 이름 : 라파
# 몸무게 : 56
# 키 : 177
# BMI : 17.87481247406556
# 결과 : 저체중
#
# 이름 : 카마
# 몸무게 : 48
# 키 : 174
# BMI : 15.854141894569956
# 결과 : 저체중
#
# 이름 : 가자
# 몸무게 : 82
# 키 : 156
# BMI : 33.694937541091385
# 결과 : 과체중
#
# 이름 : 사아
# 몸무게 : 91
# 키 : 152
# BMI : 39.387119113573405
# 결과 : 과체중
#
# 이름 : 하차
# 몸무게 : 46
# 키 : 185
# BMI : 13.440467494521547
# 결과 : 저체중
#
# 이름 : 자나
# 몸무게 : 60
# 키 : 152
# BMI : 25.969529085872576
# 결과 : 과체중
#
# 이름 : 카마
# 몸무게 : 78
# 키 : 150
# BMI : 34.666666666666664
# 결과 : 과체중
#
# 이름 : 파아
# 몸무게 : 86
# 키 : 145
# BMI : 40.903686087990486
# 결과 : 과체중
#
# 이름 : 가사
# 몸무게 : 74
# 키 : 174
# BMI : 24.441802087462015
# 결과 : 정상체중
#
# 이름 : 나라
# 몸무게 : 77
# 키 : 165
# BMI : 28.282828282828287
# 결과 : 과체중
#
# 이름 : 타타
# 몸무게 : 63
# 키 : 168
# BMI : 22.321428571428577
# 결과 : 정상체중
#
# 이름 : 파자
# 몸무게 : 70
# 키 : 181
# BMI : 21.36686914318855
# 결과 : 정상체중
#
# 이름 : 바하
# 몸무게 : 86
# 키 : 168
# BMI : 30.470521541950117
# 결과 : 과체중
#
# 이름 : 하타
# 몸무게 : 80
# 키 : 191
# BMI : 21.929223431375238
# 결과 : 정상체중
#
# 이름 : 자마
# 몸무게 : 40
# 키 : 175
# BMI : 13.061224489795919
# 결과 : 저체중
#
# 이름 : 자차
# 몸무게 : 73
# 키 : 153
# BMI : 31.184587124610193
# 결과 : 과체중
#
# 이름 : 아사
# 몸무게 : 96
# 키 : 175
# BMI : 31.346938775510203
# 결과 : 과체중
#
# 이름 : 나바
# 몸무게 : 44
# 키 : 154
# BMI : 18.55287569573284
# 결과 : 정상체중
#
# 이름 : 다사
# 몸무게 : 82
# 키 : 183
# BMI : 24.48565200513601
# 결과 : 정상체중
#
# 이름 : 가차
# 몸무게 : 73
# 키 : 165
# BMI : 26.813590449954088
# 결과 : 과체중
#
# 이름 : 다하
# 몸무게 : 69
# 키 : 183
# BMI : 20.603780345785182
# 결과 : 정상체중
#
# 이름 : 파사
# 몸무게 : 96
# 키 : 185
# BMI : 28.04967129291453
# 결과 : 과체중
#
# 이름 : 마바
# 몸무게 : 74
# 키 : 149
# BMI : 33.331831899463985
# 결과 : 과체중
#
# 이름 : 라자
# 몸무게 : 71
# 키 : 156
# BMI : 29.17488494411571
# 결과 : 과체중
#
# 이름 : 타아
# 몸무게 : 83
# 키 : 196
# BMI : 21.605581007913372
# 결과 : 정상체중
#
# 이름 : 마나
# 몸무게 : 46
# 키 : 183
# BMI : 13.735853563856788
# 결과 : 저체중
#
# 이름 : 타바
# 몸무게 : 50
# 키 : 168
# BMI : 17.71541950113379
# 결과 : 저체중
#
# 이름 : 사하
# 몸무게 : 95
# 키 : 141
# BMI : 47.784316684271424
# 결과 : 과체중
#
# 이름 : 다차
# 몸무게 : 45
# 키 : 159
# BMI : 17.799928800284796
# 결과 : 저체중
#
# 이름 : 가사
# 몸무게 : 64
# 키 : 161
# BMI : 24.690405462752206
# 결과 : 정상체중
#
# 이름 : 라아
# 몸무게 : 40
# 키 : 149
# BMI : 18.017206432142697
# 결과 : 저체중
#
# 이름 : 파바
# 몸무게 : 85
# 키 : 150
# BMI : 37.77777777777778
# 결과 : 과체중
#
# 이름 : 하마
# 몸무게 : 53
# 키 : 182
# BMI : 16.000483033450067
# 결과 : 저체중
#
# 이름 : 카바
# 몸무게 : 74
# 키 : 152
# BMI : 32.029085872576175
# 결과 : 과체중
#
# 이름 : 카마
# 몸무게 : 89
# 키 : 151
# BMI : 39.03337572913469
# 결과 : 과체중
#
# 이름 : 하아
# 몸무게 : 73
# 키 : 189
# BMI : 20.43615800229557
# 결과 : 정상체중
#
# 이름 : 바하
# 몸무게 : 70
# 키 : 192
# BMI : 18.98871527777778
# 결과 : 정상체중
#
# 이름 : 파차
# 몸무게 : 94
# 키 : 142
# BMI : 46.61773457647292
# 결과 : 과체중
#
# 이름 : 자자
# 몸무게 : 85
# 키 : 198
# BMI : 21.68146107540047
# 결과 : 정상체중
#
# 이름 : 나가
# 몸무게 : 60
# 키 : 185
# BMI : 17.531044558071585
# 결과 : 저체중
#
# 이름 : 타아
# 몸무게 : 89
# 키 : 187
# BMI : 25.45111384369012
# 결과 : 과체중
#
# 이름 : 아타
# 몸무게 : 77
# 키 : 192
# BMI : 20.887586805555557
# 결과 : 정상체중
#
# 이름 : 라사
# 몸무게 : 94
# 키 : 181
# BMI : 28.692652849424622
# 결과 : 과체중
#
# 이름 : 차마
# 몸무게 : 87
# 키 : 195
# BMI : 22.87968441814596
# 결과 : 정상체중
#
# 이름 : 라카
# 몸무게 : 45
# 키 : 193
# BMI : 12.080861231173992
# 결과 : 저체중
#
# 이름 : 사자
# 몸무게 : 98
# 키 : 173
# BMI : 32.74416118146279
# 결과 : 과체중
#
# 이름 : 파라
# 몸무게 : 74
# 키 : 163
# BMI : 27.85200797922391
# 결과 : 과체중
#
# 이름 : 가파
# 몸무게 : 68
# 키 : 165
# BMI : 24.977043158861342
# 결과 : 정상체중
#
# 이름 : 나나
# 몸무게 : 99
# 키 : 141
# BMI : 49.79628791308285
# 결과 : 과체중
#
# 이름 : 나가
# 몸무게 : 66
# 키 : 190
# BMI : 18.282548476454295
# 결과 : 저체중
#
# 이름 : 하아
# 몸무게 : 59
# 키 : 197
# BMI : 15.202659176995027
# 결과 : 저체중
#
# 이름 : 라차
# 몸무게 : 56
# 키 : 177
# BMI : 17.87481247406556
# 결과 : 저체중
#
# 이름 : 아차
# 몸무게 : 74
# 키 : 172
# BMI : 25.013520822065985
# 결과 : 과체중
#
# 이름 : 나마
# 몸무게 : 92
# 키 : 174
# BMI : 30.38710529792575
# 결과 : 과체중
#
# 이름 : 가라
# 몸무게 : 64
# 키 : 147
# BMI : 29.617289092507754
# 결과 : 과체중
#
# 이름 : 다가
# 몸무게 : 94
# 키 : 155
# BMI : 39.12591050988553
# 결과 : 과체중
#
# 이름 : 다가
# 몸무게 : 79
# 키 : 188
# BMI : 22.351742870076958
# 결과 : 정상체중
#
# 이름 : 나라
# 몸무게 : 67
# 키 : 156
# BMI : 27.531229454306374
# 결과 : 과체중
#
# 이름 : 나바
# 몸무게 : 67
# 키 : 174
# BMI : 22.12973972783723
# 결과 : 정상체중
#
# 이름 : 차다
# 몸무게 : 90
# 키 : 142
# BMI : 44.634001190240035
# 결과 : 과체중
#
# 이름 : 다파
# 몸무게 : 51
# 키 : 158
# BMI : 20.429418362441915
# 결과 : 정상체중
#
# 이름 : 라하
# 몸무게 : 50
# 키 : 145
# BMI : 23.781212841854934
# 결과 : 정상체중
#
# 이름 : 마마
# 몸무게 : 99
# 키 : 194
# BMI : 26.304601976830696
# 결과 : 과체중
#
# 이름 : 파다
# 몸무게 : 97
# 키 : 167
# BMI : 34.78073792534691
# 결과 : 과체중
#
# 이름 : 파바
# 몸무게 : 65
# 키 : 150
# BMI : 28.88888888888889
# 결과 : 과체중
#
# 이름 : 차마
# 몸무게 : 84
# 키 : 171
# BMI : 28.726787729557817
# 결과 : 과체중
#
# 이름 : 카자
# 몸무게 : 76
# 키 : 188
# BMI : 21.50294250792214
# 결과 : 정상체중
#
# 이름 : 마가
# 몸무게 : 89
# 키 : 179
# BMI : 27.776910832995224
# 결과 : 과체중
#
# 이름 : 카바
# 몸무게 : 65
# 키 : 153
# BMI : 27.76709812465291
# 결과 : 과체중
#
# 이름 : 라자
# 몸무게 : 73
# 키 : 157
# BMI : 29.61580591504726
# 결과 : 과체중
#
# 이름 : 마카
# 몸무게 : 93
# 키 : 146
# BMI : 43.62919872396323
# 결과 : 과체중
#
# 이름 : 사파
# 몸무게 : 98
# 키 : 169
# BMI : 34.31252407128602
# 결과 : 과체중
#
# 이름 : 카아
# 몸무게 : 59
# 키 : 142
# BMI : 29.260067446935132
# 결과 : 과체중
#
# 이름 : 하자
# 몸무게 : 94
# 키 : 149
# BMI : 42.340435115535335
# 결과 : 과체중
#
# 이름 : 바파
# 몸무게 : 91
# 키 : 167
# BMI : 32.62935207429452
# 결과 : 과체중
#
# 이름 : 마차
# 몸무게 : 67
# 키 : 175
# BMI : 21.877551020408163
# 결과 : 정상체중
#
# 이름 : 아다
# 몸무게 : 64
# 키 : 140
# BMI : 32.653061224489804
# 결과 : 과체중
#
# 이름 : 차마
# 몸무게 : 50
# 키 : 199
# BMI : 12.62594378929825
# 결과 : 저체중
#
# 이름 : 다가
# 몸무게 : 57
# 키 : 197
# BMI : 14.687314798113839
# 결과 : 저체중
#
# 이름 : 파타
# 몸무게 : 63
# 키 : 162
# BMI : 24.005486968449926
# 결과 : 정상체중
#
# 이름 : 차가
# 몸무게 : 56
# 키 : 170
# BMI : 19.377162629757787
# 결과 : 정상체중
#
# 이름 : 차타
# 몸무게 : 42
# 키 : 166
# BMI : 15.241689650166935
# 결과 : 저체중
#
# 이름 : 나가
# 몸무게 : 46
# 키 : 158
# BMI : 18.426534209261334
# 결과 : 저체중
#
# 이름 : 자카
# 몸무게 : 84
# 키 : 165
# BMI : 30.85399449035813
# 결과 : 과체중
#
# 이름 : 마타
# 몸무게 : 72
# 키 : 140
# BMI : 36.734693877551024
# 결과 : 과체중
#
# 이름 : 라다
# 몸무게 : 89
# 키 : 177
# BMI : 28.40818411056848
# 결과 : 과체중
#
# 이름 : 타다
# 몸무게 : 93
# 키 : 185
# BMI : 27.173119065010955
# 결과 : 과체중
#
# 이름 : 카나
# 몸무게 : 88
# 키 : 198
# BMI : 22.44668911335578
# 결과 : 정상체중
#
# 이름 : 가파
# 몸무게 : 53
# 키 : 147
# BMI : 24.526817529732984
# 결과 : 정상체중
#
# 이름 : 사마
# 몸무게 : 56
# 키 : 165
# BMI : 20.569329660238754
# 결과 : 정상체중
#
# 이름 : 아다
# 몸무게 : 98
# 키 : 141
# BMI : 49.29329510587999
# 결과 : 과체중
#
# 이름 : 마카
# 몸무게 : 76
# 키 : 197
# BMI : 19.58308639748512
# 결과 : 정상체중
#
# 이름 : 가타
# 몸무게 : 75
# 키 : 188
# BMI : 21.22000905387053
# 결과 : 정상체중
#
# 이름 : 나나
# 몸무게 : 73
# 키 : 154
# BMI : 30.78090740428403
# 결과 : 과체중
#
# 이름 : 마타
# 몸무게 : 69
# 키 : 158
# BMI : 27.639801313892
# 결과 : 과체중
#
# 이름 : 파마
# 몸무게 : 69
# 키 : 193
# BMI : 18.523987221133453
# 결과 : 정상체중
#
# 이름 : 나차
# 몸무게 : 43
# 키 : 197
# BMI : 11.079904145945529
# 결과 : 저체중
#
# 이름 : 나카
# 몸무게 : 63
# 키 : 151
# BMI : 27.630367089162757
# 결과 : 과체중
#
# 이름 : 하다
# 몸무게 : 41
# 키 : 191
# BMI : 11.23872700857981
# 결과 : 저체중
#
# 이름 : 나하
# 몸무게 : 47
# 키 : 148
# BMI : 21.4572680788897
# 결과 : 정상체중
#
# 이름 : 바하
# 몸무게 : 83
# 키 : 194
# BMI : 22.053353172494422
# 결과 : 정상체중
#
# 이름 : 차마
# 몸무게 : 97
# 키 : 185
# BMI : 28.341855368882392
# 결과 : 과체중
#
# 이름 : 바나
# 몸무게 : 42
# 키 : 188
# BMI : 11.883205070167497
# 결과 : 저체중
#
# 이름 : 파사
# 몸무게 : 50
# 키 : 199
# BMI : 12.62594378929825
# 결과 : 저체중
#
# 이름 : 나나
# 몸무게 : 91
# 키 : 193
# BMI : 24.43018604526296
# 결과 : 정상체중
#
# 이름 : 아하
# 몸무게 : 69
# 키 : 146
# BMI : 32.370050666166264
# 결과 : 과체중
#
# 이름 : 다자
# 몸무게 : 51
# 키 : 155
# BMI : 21.227887617065555
# 결과 : 정상체중
#
# 이름 : 하다
# 몸무게 : 96
# 키 : 164
# BMI : 35.693039857227845
# 결과 : 과체중
#
# 이름 : 자차
# 몸무게 : 72
# 키 : 184
# BMI : 21.266540642722116
# 결과 : 정상체중
#
# 이름 : 파나
# 몸무게 : 98
# 키 : 152
# BMI : 42.41689750692521
# 결과 : 과체중
#
# 이름 : 다파
# 몸무게 : 90
# 키 : 193
# BMI : 24.161722462347985
# 결과 : 정상체중
#
# 이름 : 사마
# 몸무게 : 86
# 키 : 187
# BMI : 24.59321112985787
# 결과 : 정상체중
#
# 이름 : 가마
# 몸무게 : 82
# 키 : 196
# BMI : 21.345272802998753
# 결과 : 정상체중
#
# 이름 : 아나
# 몸무게 : 90
# 키 : 156
# BMI : 36.98224852071006
# 결과 : 과체중
#
# 이름 : 마자
# 몸무게 : 50
# 키 : 174
# BMI : 16.514731140177037
# 결과 : 저체중
#
# 이름 : 라다
# 몸무게 : 64
# 키 : 191
# BMI : 17.54337874510019
# 결과 : 저체중
#
# 이름 : 라가
# 몸무게 : 56
# 키 : 182
# BMI : 16.9061707523246
# 결과 : 저체중
#
# 이름 : 타마
# 몸무게 : 58
# 키 : 153
# BMI : 24.77679524969029
# 결과 : 정상체중
#
# 이름 : 차마
# 몸무게 : 41
# 키 : 187
# BMI : 11.724670422374102
# 결과 : 저체중
#
# 이름 : 자아
# 몸무게 : 42
# 키 : 156
# BMI : 17.258382642998026
# 결과 : 저체중
#
# 이름 : 카아
# 몸무게 : 55
# 키 : 169
# BMI : 19.257028815517668
# 결과 : 정상체중
#
# 이름 : 다라
# 몸무게 : 93
# 키 : 159
# BMI : 36.786519520588584
# 결과 : 과체중
#
# 이름 : 라파
# 몸무게 : 99
# 키 : 156
# BMI : 40.68047337278106
# 결과 : 과체중
#
# 이름 : 자차
# 몸무게 : 52
# 키 : 187
# BMI : 14.870313706425689
# 결과 : 저체중
#
# 이름 : 바파
# 몸무게 : 89
# 키 : 167
# BMI : 31.912223457277065
# 결과 : 과체중
#
# 이름 : 나가
# 몸무게 : 57
# 키 : 196
# BMI : 14.83756768013328
# 결과 : 저체중
#
# 이름 : 나카
# 몸무게 : 59
# 키 : 189
# BMI : 16.516894823773132
# 결과 : 저체중
#
# 이름 : 자카
# 몸무게 : 77
# 키 : 174
# BMI : 25.43268595587264
# 결과 : 과체중
#
# 이름 : 자가
# 몸무게 : 70
# 키 : 176
# BMI : 22.59814049586777
# 결과 : 정상체중
#
# 이름 : 라나
# 몸무게 : 72
# 키 : 170
# BMI : 24.913494809688583
# 결과 : 정상체중
#
# 이름 : 하마
# 몸무게 : 92
# 키 : 199
# BMI : 23.23173657230878
# 결과 : 정상체중
#
# 이름 : 하타
# 몸무게 : 41
# 키 : 185
# BMI : 11.979547114682248
# 결과 : 저체중
#
# 이름 : 파자
# 몸무게 : 78
# 키 : 189
# BMI : 21.83589485176787
# 결과 : 정상체중
#
# 이름 : 카가
# 몸무게 : 96
# 키 : 151
# BMI : 42.103416516819436
# 결과 : 과체중
#
# 이름 : 사파
# 몸무게 : 76
# 키 : 143
# BMI : 37.16563157122598
# 결과 : 과체중
#
# 이름 : 카타
# 몸무게 : 41
# 키 : 141
# BMI : 20.62270509531714
# 결과 : 정상체중
#
# 이름 : 파차
# 몸무게 : 59
# 키 : 154
# BMI : 24.87771968291449
# 결과 : 정상체중
#
# 이름 : 가마
# 몸무게 : 88
# 키 : 163
# BMI : 33.12130678610411
# 결과 : 과체중
#
# 이름 : 라나
# 몸무게 : 89
# 키 : 191
# BMI : 24.39626106740495
# 결과 : 정상체중
#
# 이름 : 타파
# 몸무게 : 68
# 키 : 199
# BMI : 17.17128355344562
# 결과 : 저체중
#
# 이름 : 마차
# 몸무게 : 48
# 키 : 144
# BMI : 23.14814814814815
# 결과 : 정상체중
#
# 이름 : 카아
# 몸무게 : 42
# 키 : 198
# BMI : 10.71319253137435
# 결과 : 저체중
#
# 이름 : 라하
# 몸무게 : 78
# 키 : 146
# BMI : 36.59223118784013
# 결과 : 과체중
#
# 이름 : 카다
# 몸무게 : 64
# 키 : 170
# BMI : 22.145328719723185
# 결과 : 정상체중
#
# 이름 : 하자
# 몸무게 : 41
# 키 : 148
# BMI : 18.718042366691016
# 결과 : 정상체중
#
# 이름 : 아사
# 몸무게 : 71
# 키 : 166
# BMI : 25.76571345623458
# 결과 : 과체중
#
# 이름 : 자마
# 몸무게 : 97
# 키 : 154
# BMI : 40.90065778377467
# 결과 : 과체중
#
# 이름 : 타라
# 몸무게 : 47
# 키 : 159
# BMI : 18.59103674696412
# 결과 : 정상체중
#
# 이름 : 바바
# 몸무게 : 96
# 키 : 158
# BMI : 38.45537574106713
# 결과 : 과체중
#
# 이름 : 파마
# 몸무게 : 57
# 키 : 173
# BMI : 19.045073340238563
# 결과 : 정상체중
#
# 이름 : 가나
# 몸무게 : 96
# 키 : 199
# BMI : 24.24181207545264
# 결과 : 정상체중
#
# 이름 : 하타
# 몸무게 : 43
# 키 : 144
# BMI : 20.736882716049383
# 결과 : 정상체중
#
# 이름 : 카사
# 몸무게 : 40
# 키 : 175
# BMI : 13.061224489795919
# 결과 : 저체중
#
# 이름 : 다파
# 몸무게 : 47
# 키 : 196
# BMI : 12.23448563098709
# 결과 : 저체중
#
# 이름 : 바카
# 몸무게 : 61
# 키 : 185
# BMI : 17.82322863403944
# 결과 : 저체중
#
# 이름 : 다자
# 몸무게 : 83
# 키 : 178
# BMI : 26.19618735008206
# 결과 : 과체중
#
# 이름 : 사자
# 몸무게 : 58
# 키 : 161
# BMI : 22.375679950619187
# 결과 : 정상체중
#
# 이름 : 다나
# 몸무게 : 94
# 키 : 158
# BMI : 37.6542220797949
# 결과 : 과체중
#
# 이름 : 사나
# 몸무게 : 54
# 키 : 159
# BMI : 21.359914560341757
# 결과 : 정상체중
#
# 이름 : 카라
# 몸무게 : 99
# 키 : 153
# BMI : 42.29142637447136
# 결과 : 과체중
#
# 이름 : 나자
# 몸무게 : 89
# 키 : 160
# BMI : 34.76562499999999
# 결과 : 과체중
#
# 이름 : 바하
# 몸무게 : 78
# 키 : 169
# BMI : 27.309968138370508
# 결과 : 과체중
#
# 이름 : 카다
# 몸무게 : 50
# 키 : 146
# BMI : 23.45655845374367
# 결과 : 정상체중
#
# 이름 : 타다
# 몸무게 : 42
# 키 : 198
# BMI : 10.71319253137435
# 결과 : 저체중
#
# 이름 : 아마
# 몸무게 : 49
# 키 : 191
# BMI : 13.431649351717333
# 결과 : 저체중
#
# 이름 : 카카
# 몸무게 : 73
# 키 : 142
# BMI : 36.20313429875025
# 결과 : 과체중
#
# 이름 : 바다
# 몸무게 : 72
# 키 : 199
# BMI : 18.18135905658948
# 결과 : 저체중
#
# 이름 : 자나
# 몸무게 : 41
# 키 : 177
# BMI : 13.086916275655144
# 결과 : 저체중
#
# 이름 : 하나
# 몸무게 : 43
# 키 : 144
# BMI : 20.736882716049383
# 결과 : 정상체중
#
# 이름 : 마아
# 몸무게 : 71
# 키 : 167
# BMI : 25.458065904119906
# 결과 : 과체중
#
# 이름 : 아가
# 몸무게 : 89
# 키 : 151
# BMI : 39.03337572913469
# 결과 : 과체중
#
# 이름 : 사아
# 몸무게 : 92
# 키 : 170
# BMI : 31.83391003460208
# 결과 : 과체중
#
# 이름 : 아아
# 몸무게 : 60
# 키 : 156
# BMI : 24.654832347140037
# 결과 : 정상체중
#
# 이름 : 바바
# 몸무게 : 90
# 키 : 164
# BMI : 33.462224866151104
# 결과 : 과체중
#
# 이름 : 타마
# 몸무게 : 91
# 키 : 176
# BMI : 29.3775826446281
# 결과 : 과체중
#
# 이름 : 바마
# 몸무게 : 43
# 키 : 145
# BMI : 20.451843043995243
# 결과 : 정상체중
#
# 이름 : 사다
# 몸무게 : 89
# 키 : 195
# BMI : 23.405654174884944
# 결과 : 정상체중
#
# 이름 : 아카
# 몸무게 : 40
# 키 : 158
# BMI : 16.023073225444637
# 결과 : 저체중
#
# 이름 : 다라
# 몸무게 : 69
# 키 : 157
# BMI : 27.993022029291247
# 결과 : 과체중
#
# 이름 : 파타
# 몸무게 : 55
# 키 : 140
# BMI : 28.061224489795922
# 결과 : 과체중
#
# 이름 : 가하
# 몸무게 : 63
# 키 : 143
# BMI : 30.80835248667417
# 결과 : 과체중
#
# 이름 : 다다
# 몸무게 : 92
# 키 : 192
# BMI : 24.95659722222222
# 결과 : 정상체중
#
# 이름 : 나타
# 몸무게 : 62
# 키 : 193
# BMI : 16.64474214072861
# 결과 : 저체중
#
# 이름 : 라라
# 몸무게 : 56
# 키 : 165
# BMI : 20.569329660238754
# 결과 : 정상체중
#
# 이름 : 아차
# 몸무게 : 40
# 키 : 156
# BMI : 16.43655489809336
# 결과 : 저체중
#
# 이름 : 하라
# 몸무게 : 97
# 키 : 183
# BMI : 28.964734689002356
# 결과 : 과체중
#
# 이름 : 마하
# 몸무게 : 42
# 키 : 150
# BMI : 18.666666666666668
# 결과 : 정상체중
#
# 이름 : 하차
# 몸무게 : 73
# 키 : 196
# BMI : 19.00249895876718
# 결과 : 정상체중
#
# 이름 : 파하
# 몸무게 : 96
# 키 : 167
# BMI : 34.42217361683818
# 결과 : 과체중
#
# 이름 : 마바
# 몸무게 : 47
# 키 : 197
# BMI : 12.110592903707902
# 결과 : 저체중
#
# 이름 : 사차
# 몸무게 : 70
# 키 : 155
# BMI : 29.1363163371488
# 결과 : 과체중
#
# 이름 : 라바
# 몸무게 : 76
# 키 : 140
# BMI : 38.77551020408164
# 결과 : 과체중
#
# 이름 : 라마
# 몸무게 : 68
# 키 : 162
# BMI : 25.910684346898332
# 결과 : 과체중
#
# 이름 : 파나
# 몸무게 : 68
# 키 : 174
# BMI : 22.460034350640772
# 결과 : 정상체중
#
# 이름 : 마라
# 몸무게 : 69
# 키 : 171
# BMI : 23.59700420642249
# 결과 : 정상체중
#
# 이름 : 다자
# 몸무게 : 68
# 키 : 160
# BMI : 26.562499999999996
# 결과 : 과체중
#
# 이름 : 아타
# 몸무게 : 99
# 키 : 158
# BMI : 39.65710623297548
# 결과 : 과체중
#
# 이름 : 타파
# 몸무게 : 98
# 키 : 148
# BMI : 44.74068663257852
# 결과 : 과체중
#
# 이름 : 파사
# 몸무게 : 97
# 키 : 177
# BMI : 30.961728749720702
# 결과 : 과체중
#
# 이름 : 사라
# 몸무게 : 41
# 키 : 172
# BMI : 13.858842617631153
# 결과 : 저체중
#
# 이름 : 아마
# 몸무게 : 85
# 키 : 197
# BMI : 21.902136102450463
# 결과 : 정상체중
#
# 이름 : 라타
# 몸무게 : 69
# 키 : 150
# BMI : 30.666666666666668
# 결과 : 과체중
#
# 이름 : 다가
# 몸무게 : 72
# 키 : 170
# BMI : 24.913494809688583
# 결과 : 정상체중
#
# 이름 : 타하
# 몸무게 : 89
# 키 : 159
# BMI : 35.20430362722993
# 결과 : 과체중
#
# 이름 : 타다
# 몸무게 : 55
# 키 : 144
# BMI : 26.52391975308642
# 결과 : 과체중
#
# 이름 : 가하
# 몸무게 : 57
# 키 : 193
# BMI : 15.302424226153724
# 결과 : 저체중
#
# 이름 : 사마
# 몸무게 : 69
# 키 : 156
# BMI : 28.353057199211044
# 결과 : 과체중
#
# 이름 : 카사
# 몸무게 : 80
# 키 : 143
# BMI : 39.121717443395774
# 결과 : 과체중
#
# 이름 : 아라
# 몸무게 : 80
# 키 : 153
# BMI : 34.17488999957281
# 결과 : 과체중
#
# 이름 : 아타
# 몸무게 : 85
# 키 : 166
# BMI : 30.84627667295689
# 결과 : 과체중
#
# 이름 : 차나
# 몸무게 : 44
# 키 : 142
# BMI : 21.821067248561793
# 결과 : 정상체중
#
# 이름 : 아파
# 몸무게 : 58
# 키 : 166
# BMI : 21.04804761213529
# 결과 : 정상체중
#
# 이름 : 파아
# 몸무게 : 58
# 키 : 142
# BMI : 28.76413410037691
# 결과 : 과체중
#
# 이름 : 가마
# 몸무게 : 56
# 키 : 162
# BMI : 21.338210638622158
# 결과 : 정상체중
#
# 이름 : 아다
# 몸무게 : 90
# 키 : 170
# BMI : 31.14186851211073
# 결과 : 과체중
#
# 이름 : 파가
# 몸무게 : 69
# 키 : 173
# BMI : 23.054562464499313
# 결과 : 정상체중
#
# 이름 : 카마
# 몸무게 : 62
# 키 : 145
# BMI : 29.48870392390012
# 결과 : 과체중
#
# 이름 : 바아
# 몸무게 : 75
# 키 : 168
# BMI : 26.573129251700685
# 결과 : 과체중
#
# 이름 : 파라
# 몸무게 : 64
# 키 : 188
# BMI : 18.107741059302853
# 결과 : 저체중
#
# 이름 : 가아
# 몸무게 : 41
# 키 : 179
# BMI : 12.796104990480947
# 결과 : 저체중
#
# 이름 : 바다
# 몸무게 : 97
# 키 : 151
# BMI : 42.54199377220297
# 결과 : 과체중
#
# 이름 : 나파
# 몸무게 : 52
# 키 : 154
# BMI : 21.926125822229718
# 결과 : 정상체중
#
# 이름 : 차자
# 몸무게 : 80
# 키 : 166
# BMI : 29.03178980984178
# 결과 : 과체중
#
# 이름 : 자사
# 몸무게 : 87
# 키 : 169
# BMI : 30.461118308182492
# 결과 : 과체중
#
# 이름 : 나차
# 몸무게 : 63
# 키 : 161
# BMI : 24.3046178773967
# 결과 : 정상체중
#
# 이름 : 다나
# 몸무게 : 62
# 키 : 172
# BMI : 20.9572742022715
# 결과 : 정상체중
#
# 이름 : 마카
# 몸무게 : 62
# 키 : 180
# BMI : 19.1358024691358
# 결과 : 정상체중
#
# 이름 : 차아
# 몸무게 : 48
# 키 : 147
# BMI : 22.212966819380814
# 결과 : 정상체중
#
# 이름 : 바아
# 몸무게 : 70
# 키 : 161
# BMI : 27.005130974885226
# 결과 : 과체중
#
# 이름 : 사라
# 몸무게 : 87
# 키 : 154
# BMI : 36.68409512565357
# 결과 : 과체중
#
# 이름 : 나자
# 몸무게 : 59
# 키 : 154
# BMI : 24.87771968291449
# 결과 : 정상체중
#
# 이름 : 파차
# 몸무게 : 82
# 키 : 168
# BMI : 29.053287981859416
# 결과 : 과체중
#
# 이름 : 하타
# 몸무게 : 61
# 키 : 145
# BMI : 29.01307966706302
# 결과 : 과체중
#
# 이름 : 하타
# 몸무게 : 41
# 키 : 183
# BMI : 12.242826002568005
# 결과 : 저체중
#
# 이름 : 마나
# 몸무게 : 47
# 키 : 172
# BMI : 15.886965927528395
# 결과 : 저체중
#
# 이름 : 마다
# 몸무게 : 61
# 키 : 143
# BMI : 29.830309550589273
# 결과 : 과체중
#
# 이름 : 마하
# 몸무게 : 46
# 키 : 171
# BMI : 15.731336137614994
# 결과 : 저체중
#
# 이름 : 바바
# 몸무게 : 54
# 키 : 168
# BMI : 19.13265306122449
# 결과 : 정상체중
#
# 이름 : 아아
# 몸무게 : 49
# 키 : 172
# BMI : 16.563007030827475
# 결과 : 저체중
#
# 이름 : 타마
# 몸무게 : 56
# 키 : 172
# BMI : 18.92915089237426
# 결과 : 정상체중
#
# 이름 : 다하
# 몸무게 : 58
# 키 : 174
# BMI : 19.157088122605362
# 결과 : 정상체중
#
# 이름 : 카마
# 몸무게 : 54
# 키 : 190
# BMI : 14.958448753462605
# 결과 : 저체중
#
# 이름 : 파자
# 몸무게 : 85
# 키 : 170
# BMI : 29.411764705882355
# 결과 : 과체중
#
# 이름 : 파다
# 몸무게 : 57
# 키 : 184
# BMI : 16.836011342155007
# 결과 : 저체중
#
# 이름 : 자타
# 몸무게 : 50
# 키 : 168
# BMI : 17.71541950113379
# 결과 : 저체중
#
# 이름 : 사바
# 몸무게 : 79
# 키 : 175
# BMI : 25.79591836734694
# 결과 : 과체중
#
# 이름 : 나자
# 몸무게 : 80
# 키 : 155
# BMI : 33.29864724245577
# 결과 : 과체중
#
# 이름 : 하마
# 몸무게 : 59
# 키 : 170
# BMI : 20.41522491349481
# 결과 : 정상체중
#
# 이름 : 다마
# 몸무게 : 60
# 키 : 141
# BMI : 30.179568432171422
# 결과 : 과체중
#
# 이름 : 바다
# 몸무게 : 62
# 키 : 199
# BMI : 15.65617029872983
# 결과 : 저체중
#
# 이름 : 바자
# 몸무게 : 55
# 키 : 195
# BMI : 14.464168310322158
# 결과 : 저체중
#
# 이름 : 다사
# 몸무게 : 74
# 키 : 159
# BMI : 29.270994027135
# 결과 : 과체중
#
# 이름 : 라마
# 몸무게 : 41
# 키 : 166
# BMI : 14.878792277543912
# 결과 : 저체중
#
# 이름 : 가다
# 몸무게 : 71
# 키 : 199
# BMI : 17.928840180803515
# 결과 : 저체중
#
# 이름 : 바아
# 몸무게 : 57
# 키 : 154
# BMI : 24.034407151290267
# 결과 : 정상체중
#
# 이름 : 자나
# 몸무게 : 56
# 키 : 178
# BMI : 17.67453604342886
# 결과 : 저체중
#
# 이름 : 파라
# 몸무게 : 58
# 키 : 183
# BMI : 17.319119710949863
# 결과 : 저체중
#
# 이름 : 자타
# 몸무게 : 77
# 키 : 186
# BMI : 22.25690831309978
# 결과 : 정상체중
#
# 이름 : 마나
# 몸무게 : 71
# 키 : 175
# BMI : 23.183673469387756
# 결과 : 정상체중
#
# 이름 : 다차
# 몸무게 : 77
# 키 : 197
# BMI : 19.840758586925713
# 결과 : 정상체중
#
# 이름 : 타자
# 몸무게 : 82
# 키 : 176
# BMI : 26.47210743801653
# 결과 : 과체중
#
# 이름 : 나마
# 몸무게 : 50
# 키 : 172
# BMI : 16.901027582477017
# 결과 : 저체중
#
# 이름 : 아가
# 몸무게 : 48
# 키 : 185
# BMI : 14.024835646457266
# 결과 : 저체중
#
# 이름 : 자타
# 몸무게 : 61
# 키 : 162
# BMI : 23.243408017070564
# 결과 : 정상체중
#
# 이름 : 하다
# 몸무게 : 65
# 키 : 185
# BMI : 18.991964937910883
# 결과 : 정상체중
#
# 이름 : 파마
# 몸무게 : 60
# 키 : 177
# BMI : 19.15158479364167
# 결과 : 정상체중
#
# 이름 : 하라
# 몸무게 : 58
# 키 : 174
# BMI : 19.157088122605362
# 결과 : 정상체중
#
# 이름 : 하파
# 몸무게 : 41
# 키 : 165
# BMI : 15.059687786960517
# 결과 : 저체중
#
# 이름 : 차자
# 몸무게 : 81
# 키 : 192
# BMI : 21.97265625
# 결과 : 정상체중
#
# 이름 : 라타
# 몸무게 : 42
# 키 : 172
# BMI : 14.196863169280693
# 결과 : 저체중
#
# 이름 : 라차
# 몸무게 : 59
# 키 : 189
# BMI : 16.516894823773132
# 결과 : 저체중
#
# 이름 : 마가
# 몸무게 : 85
# 키 : 143
# BMI : 41.566824783608006
# 결과 : 과체중
#
# 이름 : 하다
# 몸무게 : 77
# 키 : 185
# BMI : 22.498173849525198
# 결과 : 정상체중
#
# 이름 : 다다
# 몸무게 : 57
# 키 : 173
# BMI : 19.045073340238563
# 결과 : 정상체중
#
# 이름 : 나마
# 몸무게 : 49
# 키 : 172
# BMI : 16.563007030827475
# 결과 : 저체중
#
# 이름 : 파가
# 몸무게 : 92
# 키 : 191
# BMI : 25.218606946081522
# 결과 : 과체중
#
# 이름 : 파라
# 몸무게 : 64
# 키 : 195
# BMI : 16.8310322156476
# 결과 : 저체중
#
# 이름 : 사바
# 몸무게 : 54
# 키 : 172
# BMI : 18.25310978907518
# 결과 : 저체중
#
# 이름 : 다마
# 몸무게 : 68
# 키 : 185
# BMI : 19.86851716581446
# 결과 : 정상체중
#
# 이름 : 바마
# 몸무게 : 81
# 키 : 199
# BMI : 20.454028938663164
# 결과 : 정상체중
#
# 이름 : 가카
# 몸무게 : 66
# 키 : 198
# BMI : 16.835016835016834
# 결과 : 저체중
#
# 이름 : 타하
# 몸무게 : 91
# 키 : 145
# BMI : 43.28180737217598
# 결과 : 과체중
#
# 이름 : 마바
# 몸무게 : 59
# 키 : 158
# BMI : 23.634033007530842
# 결과 : 정상체중
#
# 이름 : 사나
# 몸무게 : 55
# 키 : 160
# BMI : 21.484374999999996
# 결과 : 정상체중
#
# 이름 : 바차
# 몸무게 : 95
# 키 : 150
# BMI : 42.22222222222222
# 결과 : 과체중
#
# 이름 : 차가
# 몸무게 : 54
# 키 : 141
# BMI : 27.16161158895428
# 결과 : 과체중
#
# 이름 : 차라
# 몸무게 : 83
# 키 : 168
# BMI : 29.40759637188209
# 결과 : 과체중
#
# 이름 : 바가
# 몸무게 : 55
# 키 : 155
# BMI : 22.892819979188342
# 결과 : 정상체중
#
# 이름 : 자아
# 몸무게 : 85
# 키 : 163
# BMI : 31.992171327486922
# 결과 : 과체중
#
# 이름 : 자자
# 몸무게 : 55
# 키 : 157
# BMI : 22.313278429145196
# 결과 : 정상체중
#
# 이름 : 아자
# 몸무게 : 99
# 키 : 186
# BMI : 28.61602497398543
# 결과 : 과체중
#
# 이름 : 파바
# 몸무게 : 80
# 키 : 148
# BMI : 36.52300949598247
# 결과 : 과체중
#
# 이름 : 다자
# 몸무게 : 61
# 키 : 163
# BMI : 22.95908765854944
# 결과 : 정상체중
#
# 이름 : 다하
# 몸무게 : 98
# 키 : 155
# BMI : 40.79084287200832
# 결과 : 과체중
#
# 이름 : 라차
# 몸무게 : 72
# 키 : 166
# BMI : 26.1286108288576
# 결과 : 과체중
#
# 이름 : 하바
# 몸무게 : 94
# 키 : 196
# BMI : 24.46897126197418
# 결과 : 정상체중
#
# 이름 : 자파
# 몸무게 : 78
# 키 : 159
# BMI : 30.853209920493647
# 결과 : 과체중
#
# 이름 : 차마
# 몸무게 : 99
# 키 : 173
# BMI : 33.07828527515119
# 결과 : 과체중
#
# 이름 : 나가
# 몸무게 : 72
# 키 : 147
# BMI : 33.31945022907122
# 결과 : 과체중
#
# 이름 : 타파
# 몸무게 : 45
# 키 : 153
# BMI : 19.223375624759708
# 결과 : 정상체중
#
# 이름 : 마가
# 몸무게 : 85
# 키 : 177
# BMI : 27.13141179099237
# 결과 : 과체중
#
# 이름 : 나라
# 몸무게 : 94
# 키 : 161
# BMI : 36.264033023417305
# 결과 : 과체중
#
# 이름 : 마다
# 몸무게 : 73
# 키 : 182
# BMI : 22.03840115928028
# 결과 : 정상체중
#
# 이름 : 파파
# 몸무게 : 54
# 키 : 173
# BMI : 18.042701059173375
# 결과 : 저체중
#
# 이름 : 차나
# 몸무게 : 79
# 키 : 148
# BMI : 36.06647187728269
# 결과 : 과체중
#
# 이름 : 타바
# 몸무게 : 84
# 키 : 145
# BMI : 39.95243757431629
# 결과 : 과체중
#
# 이름 : 파마
# 몸무게 : 96
# 키 : 177
# BMI : 30.642535669826675
# 결과 : 과체중
#
# 이름 : 다아
# 몸무게 : 95
# 키 : 192
# BMI : 25.770399305555557
# 결과 : 과체중
#
# 이름 : 카하
# 몸무게 : 53
# 키 : 160
# BMI : 20.703124999999996
# 결과 : 정상체중
#
# 이름 : 파차
# 몸무게 : 56
# 키 : 199
# BMI : 14.141057044014039
# 결과 : 저체중
#
# 이름 : 마마
# 몸무게 : 51
# 키 : 198
# BMI : 13.008876645240282
# 결과 : 저체중
#
# 이름 : 아나
# 몸무게 : 45
# 키 : 144
# BMI : 21.70138888888889
# 결과 : 정상체중
#
# 이름 : 카나
# 몸무게 : 83
# 키 : 158
# BMI : 33.247876942797625
# 결과 : 과체중
#
# 이름 : 가라
# 몸무게 : 44
# 키 : 178
# BMI : 13.887135462694104
# 결과 : 저체중
#
# 이름 : 다나
# 몸무게 : 57
# 키 : 177
# BMI : 18.194005553959588
# 결과 : 저체중
#
# 이름 : 가아
# 몸무게 : 60
# 키 : 140
# BMI : 30.612244897959187
# 결과 : 과체중
#
# 이름 : 아라
# 몸무게 : 70
# 키 : 199
# BMI : 17.67632130501755
# 결과 : 저체중
#
# 이름 : 카사
# 몸무게 : 54
# 키 : 150
# BMI : 24.0
# 결과 : 정상체중
#
# 이름 : 파타
# 몸무게 : 41
# 키 : 179
# BMI : 12.796104990480947
# 결과 : 저체중
#
# 이름 : 차아
# 몸무게 : 59
# 키 : 165
# BMI : 21.6712580348944
# 결과 : 정상체중
#
# 이름 : 마사
# 몸무게 : 63
# 키 : 167
# BMI : 22.589551436050055
# 결과 : 정상체중
#
# 이름 : 카하
# 몸무게 : 64
# 키 : 177
# BMI : 20.428357113217785
# 결과 : 정상체중
#
# 이름 : 하나
# 몸무게 : 64
# 키 : 176
# BMI : 20.66115702479339
# 결과 : 정상체중
#
# 이름 : 마사
# 몸무게 : 60
# 키 : 193
# BMI : 16.107814974898655
# 결과 : 저체중
#
# 이름 : 바파
# 몸무게 : 79
# 키 : 146
# BMI : 37.061362356915
# 결과 : 과체중
#
# 이름 : 라카
# 몸무게 : 74
# 키 : 174
# BMI : 24.441802087462015
# 결과 : 정상체중
#
# 이름 : 하나
# 몸무게 : 53
# 키 : 198
# BMI : 13.519028670543822
# 결과 : 저체중
#
# 이름 : 마라
# 몸무게 : 90
# 키 : 162
# BMI : 34.293552812071326
# 결과 : 과체중
#
# 이름 : 자차
# 몸무게 : 41
# 키 : 196
# BMI : 10.672636401499377
# 결과 : 저체중
#
# 이름 : 카파
# 몸무게 : 84
# 키 : 147
# BMI : 38.87269193391643
# 결과 : 과체중
#
# 이름 : 하나
# 몸무게 : 47
# 키 : 168
# BMI : 16.65249433106576
# 결과 : 저체중
#
# 이름 : 라아
# 몸무게 : 71
# 키 : 169
# BMI : 24.859073561850078
# 결과 : 정상체중
#
# 이름 : 다마
# 몸무게 : 56
# 키 : 162
# BMI : 21.338210638622158
# 결과 : 정상체중
#
# 이름 : 파차
# 몸무게 : 65
# 키 : 148
# BMI : 29.674945215485756
# 결과 : 과체중
#
# 이름 : 아자
# 몸무게 : 65
# 키 : 147
# BMI : 30.080059234578187
# 결과 : 과체중
#
# 이름 : 라타
# 몸무게 : 57
# 키 : 147
# BMI : 26.377898098014718
# 결과 : 과체중
#
# 이름 : 차자
# 몸무게 : 89
# 키 : 146
# BMI : 41.75267404766373
# 결과 : 과체중
#
# 이름 : 다카
# 몸무게 : 85
# 키 : 166
# BMI : 30.84627667295689
# 결과 : 과체중
#
# 이름 : 라다
# 몸무게 : 56
# 키 : 146
# BMI : 26.27134546819291
# 결과 : 과체중
#
# 이름 : 파차
# 몸무게 : 41
# 키 : 199
# BMI : 10.353273907224565
# 결과 : 저체중
#
# 이름 : 나마
# 몸무게 : 69
# 키 : 149
# BMI : 31.07968109544615
# 결과 : 과체중
#
# 이름 : 나라
# 몸무게 : 66
# 키 : 198
# BMI : 16.835016835016834
# 결과 : 저체중
#
# 이름 : 차카
# 몸무게 : 83
# 키 : 181
# BMI : 25.33500198406642
# 결과 : 과체중
#
# 이름 : 차가
# 몸무게 : 86
# 키 : 166
# BMI : 31.20917404557991
# 결과 : 과체중
#
# 이름 : 파아
# 몸무게 : 65
# 키 : 151
# BMI : 28.507521599929827
# 결과 : 과체중
#
# 이름 : 차자
# 몸무게 : 88
# 키 : 162
# BMI : 33.53147386069196
# 결과 : 과체중
#
# 이름 : 파차
# 몸무게 : 89
# 키 : 186
# BMI : 25.725517400855587
# 결과 : 과체중
#
# 이름 : 마라
# 몸무게 : 76
# 키 : 167
# BMI : 27.250887446663558
# 결과 : 과체중
#
# 이름 : 마사
# 몸무게 : 58
# 키 : 197
# BMI : 14.944986987554433
# 결과 : 저체중
#
# 이름 : 카하
# 몸무게 : 88
# 키 : 163
# BMI : 33.12130678610411
# 결과 : 과체중
#
# 이름 : 하마
# 몸무게 : 79
# 키 : 145
# BMI : 37.574316290130795
# 결과 : 과체중
#
# 이름 : 나자
# 몸무게 : 87
# 키 : 196
# BMI : 22.646813827571847
# 결과 : 정상체중
#
# 이름 : 자마
# 몸무게 : 57
# 키 : 165
# BMI : 20.936639118457304
# 결과 : 정상체중
#
# 이름 : 타하
# 몸무게 : 89
# 키 : 180
# BMI : 27.469135802469133
# 결과 : 과체중
#
# 이름 : 자나
# 몸무게 : 66
# 키 : 157
# BMI : 26.775934114974238
# 결과 : 과체중
#
# 이름 : 타하
# 몸무게 : 48
# 키 : 169
# BMI : 16.806134238997235
# 결과 : 저체중
#
# 이름 : 카타
# 몸무게 : 92
# 키 : 151
# BMI : 40.349107495285295
# 결과 : 과체중
#
# 이름 : 바라
# 몸무게 : 82
# 키 : 146
# BMI : 38.46875586413962
# 결과 : 과체중
#
# 이름 : 다파
# 몸무게 : 45
# 키 : 182
# BMI : 13.58531578311798
# 결과 : 저체중
#
# 이름 : 나사
# 몸무게 : 51
# 키 : 198
# BMI : 13.008876645240282
# 결과 : 저체중
#
# 이름 : 하가
# 몸무게 : 74
# 키 : 187
# BMI : 21.161600274528865
# 결과 : 정상체중
#
# 이름 : 마자
# 몸무게 : 82
# 키 : 191
# BMI : 22.47745401715962
# 결과 : 정상체중
#
# 이름 : 자하
# 몸무게 : 69
# 키 : 192
# BMI : 18.717447916666668
# 결과 : 정상체중
#
# 이름 : 가타
# 몸무게 : 53
# 키 : 183
# BMI : 15.826092149661081
# 결과 : 저체중
#
# 이름 : 자하
# 몸무게 : 43
# 키 : 141
# BMI : 21.628690709722854
# 결과 : 정상체중
#
# 이름 : 나타
# 몸무게 : 67
# 키 : 181
# BMI : 20.45114617990904
# 결과 : 정상체중
#
# 이름 : 가다
# 몸무게 : 76
# 키 : 166
# BMI : 27.58020031934969
# 결과 : 과체중
#
# 이름 : 바카
# 몸무게 : 69
# 키 : 175
# BMI : 22.53061224489796
# 결과 : 정상체중
#
# 이름 : 가자
# 몸무게 : 77
# 키 : 152
# BMI : 33.3275623268698
# 결과 : 과체중
#
# 이름 : 사자
# 몸무게 : 98
# 키 : 175
# BMI : 32.0
# 결과 : 과체중
#
# 이름 : 라마
# 몸무게 : 43
# 키 : 170
# BMI : 14.878892733564015
# 결과 : 저체중
#
# 이름 : 나아
# 몸무게 : 55
# 키 : 148
# BMI : 25.10956902848795
# 결과 : 과체중
#
# 이름 : 가다
# 몸무게 : 86
# 키 : 194
# BMI : 22.85046232330747
# 결과 : 정상체중
#
# 이름 : 다사
# 몸무게 : 47
# 키 : 176
# BMI : 15.173037190082646
# 결과 : 저체중
#
# 이름 : 파사
# 몸무게 : 59
# 키 : 157
# BMI : 23.93606231490121
# 결과 : 정상체중
#
# 이름 : 가마
# 몸무게 : 56
# 키 : 186
# BMI : 16.18684240952711
# 결과 : 저체중
#
# 이름 : 타다
# 몸무게 : 67
# 키 : 145
# BMI : 31.86682520808561
# 결과 : 과체중
#
# 이름 : 나바
# 몸무게 : 98
# 키 : 165
# BMI : 35.99632690541782
# 결과 : 과체중
#
# 이름 : 하라
# 몸무게 : 99
# 키 : 178
# BMI : 31.246054791061734
# 결과 : 과체중
#
# 이름 : 아타
# 몸무게 : 41
# 키 : 156
# BMI : 16.847468770545692
# 결과 : 저체중
#
# 이름 : 사자
# 몸무게 : 40
# 키 : 172
# BMI : 13.520822065981614
# 결과 : 저체중
#
# 이름 : 사마
# 몸무게 : 43
# 키 : 178
# BMI : 13.571518747632874
# 결과 : 저체중
#
# 이름 : 다사
# 몸무게 : 49
# 키 : 175
# BMI : 16.0
# 결과 : 저체중
#
# 이름 : 라마
# 몸무게 : 64
# 키 : 142
# BMI : 31.739734179726245
# 결과 : 과체중
#
# 이름 : 바마
# 몸무게 : 65
# 키 : 195
# BMI : 17.094017094017094
# 결과 : 저체중
#
# 이름 : 라카
# 몸무게 : 59
# 키 : 167
# BMI : 21.15529420201513
# 결과 : 정상체중
#
# 이름 : 다다
# 몸무게 : 70
# 키 : 176
# BMI : 22.59814049586777
# 결과 : 정상체중
#
# 이름 : 마카
# 몸무게 : 73
# 키 : 165
# BMI : 26.813590449954088
# 결과 : 과체중
#
# 이름 : 마라
# 몸무게 : 68
# 키 : 158
# BMI : 27.239224483255885
# 결과 : 과체중
#
# 이름 : 타하
# 몸무게 : 60
# 키 : 150
# BMI : 26.666666666666668
# 결과 : 과체중
#
# 이름 : 카타
# 몸무게 : 83
# 키 : 186
# BMI : 23.991212856977683
# 결과 : 정상체중
#
# 이름 : 타다
# 몸무게 : 64
# 키 : 160
# BMI : 24.999999999999996
# 결과 : 정상체중
#
# 이름 : 나나
# 몸무게 : 85
# 키 : 149
# BMI : 38.28656366830323
# 결과 : 과체중
#
# 이름 : 사차
# 몸무게 : 96
# 키 : 182
# BMI : 28.982007003985025
# 결과 : 과체중
#
# 이름 : 아마
# 몸무게 : 49
# 키 : 197
# BMI : 12.62593728258909
# 결과 : 저체중
#
# 이름 : 아카
# 몸무게 : 52
# 키 : 156
# BMI : 21.367521367521366
# 결과 : 정상체중
#
# 이름 : 차마
# 몸무게 : 63
# 키 : 171
# BMI : 21.545090797168363
# 결과 : 정상체중
#
# 이름 : 카차
# 몸무게 : 82
# 키 : 194
# BMI : 21.787650122223404
# 결과 : 정상체중
#
# 이름 : 다바
# 몸무게 : 83
# 키 : 150
# BMI : 36.888888888888886
# 결과 : 과체중
#
# 이름 : 타하
# 몸무게 : 42
# 키 : 171
# BMI : 14.363393864778908
# 결과 : 저체중
#
# 이름 : 라가
# 몸무게 : 63
# 키 : 194
# BMI : 16.73929216707408
# 결과 : 저체중
#
# 이름 : 마차
# 몸무게 : 81
# 키 : 164
# BMI : 30.116002379535995
# 결과 : 과체중
#
# 이름 : 자사
# 몸무게 : 90
# 키 : 177
# BMI : 28.72737719046251
# 결과 : 과체중
#
# 이름 : 카사
# 몸무게 : 80
# 키 : 144
# BMI : 38.58024691358025
# 결과 : 과체중
#
# 이름 : 파하
# 몸무게 : 91
# 키 : 180
# BMI : 28.086419753086417
# 결과 : 과체중
#
# 이름 : 가타
# 몸무게 : 86
# 키 : 145
# BMI : 40.903686087990486
# 결과 : 과체중
#
# 이름 : 아바
# 몸무게 : 51
# 키 : 183
# BMI : 15.228881125145568
# 결과 : 저체중
#
# 이름 : 타바
# 몸무게 : 74
# 키 : 177
# BMI : 23.620287912158062
# 결과 : 정상체중
#
# 이름 : 바타
# 몸무게 : 81
# 키 : 181
# BMI : 24.724520008546747
# 결과 : 정상체중
#
# 이름 : 아다
# 몸무게 : 62
# 키 : 155
# BMI : 25.806451612903224
# 결과 : 과체중
#
# 이름 : 바카
# 몸무게 : 62
# 키 : 149
# BMI : 27.92666996982118
# 결과 : 과체중
#
# 이름 : 아마
# 몸무게 : 55
# 키 : 146
# BMI : 25.802214299118038
# 결과 : 과체중
#
# 이름 : 타자
# 몸무게 : 61
# 키 : 145
# BMI : 29.01307966706302
# 결과 : 과체중
#
# 이름 : 가다
# 몸무게 : 49
# 키 : 142
# BMI : 24.300733981352906
# 결과 : 정상체중
#
# 이름 : 파바
# 몸무게 : 83
# 키 : 143
# BMI : 40.58878184752311
# 결과 : 과체중
#
# 이름 : 타파
# 몸무게 : 46
# 키 : 177
# BMI : 14.682881675125282
# 결과 : 저체중
#
# 이름 : 다사
# 몸무게 : 59
# 키 : 199
# BMI : 14.898613671371935
# 결과 : 저체중
#
# 이름 : 차하
# 몸무게 : 71
# 키 : 142
# BMI : 35.2112676056338
# 결과 : 과체중
#
# 이름 : 차사
# 몸무게 : 77
# 키 : 196
# BMI : 20.04373177842566
# 결과 : 정상체중
#
# 이름 : 나하
# 몸무게 : 91
# 키 : 149
# BMI : 40.98914463312463
# 결과 : 과체중
#
# 이름 : 하라
# 몸무게 : 63
# 키 : 181
# BMI : 19.230182228869694
# 결과 : 정상체중
#
# 이름 : 라타
# 몸무게 : 95
# 키 : 163
# BMI : 35.75595618954421
# 결과 : 과체중
#
# 이름 : 바카
# 몸무게 : 46
# 키 : 148
# BMI : 21.00073046018992
# 결과 : 정상체중
#
# 이름 : 마차
# 몸무게 : 68
# 키 : 150
# BMI : 30.22222222222222
# 결과 : 과체중
#
# 이름 : 자카
# 몸무게 : 78
# 키 : 144
# BMI : 37.61574074074074
# 결과 : 과체중
#
# 이름 : 가라
# 몸무게 : 51
# 키 : 180
# BMI : 15.74074074074074
# 결과 : 저체중
#
# 이름 : 파카
# 몸무게 : 66
# 키 : 168
# BMI : 23.384353741496604
# 결과 : 정상체중
#
# 이름 : 차파
# 몸무게 : 88
# 키 : 162
# BMI : 33.53147386069196
# 결과 : 과체중
#
# 이름 : 바라
# 몸무게 : 43
# 키 : 187
# BMI : 12.296605564928935
# 결과 : 저체중
#
# 이름 : 차파
# 몸무게 : 83
# 키 : 159
# BMI : 32.83097978719196
# 결과 : 과체중
#
# 이름 : 라라
# 몸무게 : 45
# 키 : 189
# BMI : 12.597631645250694
# 결과 : 저체중
#
# 이름 : 파카
# 몸무게 : 81
# 키 : 167
# BMI : 29.043708989207214
# 결과 : 과체중
#
# 이름 : 사파
# 몸무게 : 95
# 키 : 149
# BMI : 42.790865276338906
# 결과 : 과체중
#
# 이름 : 파가
# 몸무게 : 52
# 키 : 188
# BMI : 14.712539610683569
# 결과 : 저체중
#
# 이름 : 아타
# 몸무게 : 52
# 키 : 189
# BMI : 14.557263234511913
# 결과 : 저체중
#
# 이름 : 하마
# 몸무게 : 50
# 키 : 184
# BMI : 14.768431001890358
# 결과 : 저체중
#
# 이름 : 자타
# 몸무게 : 54
# 키 : 152
# BMI : 23.372576177285318
# 결과 : 정상체중
#
# 이름 : 카나
# 몸무게 : 83
# 키 : 195
# BMI : 21.827744904667984
# 결과 : 정상체중
#
# 이름 : 나파
# 몸무게 : 78
# 키 : 167
# BMI : 27.968016063681024
# 결과 : 과체중
#
# 이름 : 카자
# 몸무게 : 47
# 키 : 180
# BMI : 14.506172839506172
# 결과 : 저체중
#
# 이름 : 차파
# 몸무게 : 96
# 키 : 176
# BMI : 30.991735537190085
# 결과 : 과체중
#
# 이름 : 하바
# 몸무게 : 42
# 키 : 159
# BMI : 16.61326688026581
# 결과 : 저체중
#
# 이름 : 가타
# 몸무게 : 47
# 키 : 182
# BMI : 14.189107595701001
# 결과 : 저체중
#
# 이름 : 라라
# 몸무게 : 77
# 키 : 152
# BMI : 33.3275623268698
# 결과 : 과체중
#
# 이름 : 아사
# 몸무게 : 66
# 키 : 153
# BMI : 28.194284249647573
# 결과 : 과체중
#
# 이름 : 아하
# 몸무게 : 90
# 키 : 161
# BMI : 34.72088268199529
# 결과 : 과체중
#
# 이름 : 아바
# 몸무게 : 73
# 키 : 153
# BMI : 31.184587124610193
# 결과 : 과체중
#
# 이름 : 자카
# 몸무게 : 72
# 키 : 152
# BMI : 31.16343490304709
# 결과 : 과체중
#
# 이름 : 하바
# 몸무게 : 59
# 키 : 164
# BMI : 21.936347412254616
# 결과 : 정상체중
#
# 이름 : 나차
# 몸무게 : 86
# 키 : 168
# BMI : 30.470521541950117
# 결과 : 과체중
#
# 이름 : 가타
# 몸무게 : 48
# 키 : 154
# BMI : 20.23950075898128
# 결과 : 정상체중
#
# 이름 : 타타
# 몸무게 : 99
# 키 : 178
# BMI : 31.246054791061734
# 결과 : 과체중
#
# 이름 : 하바
# 몸무게 : 42
# 키 : 181
# BMI : 12.820121485913129
# 결과 : 저체중
#
# 이름 : 차차
# 몸무게 : 62
# 키 : 155
# BMI : 25.806451612903224
# 결과 : 과체중
#
# 이름 : 타사
# 몸무게 : 59
# 키 : 170
# BMI : 20.41522491349481
# 결과 : 정상체중
#
# 이름 : 라사
# 몸무게 : 64
# 키 : 163
# BMI : 24.088223117166624
# 결과 : 정상체중
#
# 이름 : 하아
# 몸무게 : 51
# 키 : 169
# BMI : 17.856517628934565
# 결과 : 저체중
#
# 이름 : 다바
# 몸무게 : 69
# 키 : 198
# BMI : 17.600244872972148
# 결과 : 저체중
#
# 이름 : 나카
# 몸무게 : 60
# 키 : 153
# BMI : 25.63116749967961
# 결과 : 과체중
#
# 이름 : 나다
# 몸무게 : 51
# 키 : 172
# BMI : 17.239048134126556
# 결과 : 저체중
#
# 이름 : 가다
# 몸무게 : 87
# 키 : 180
# BMI : 26.85185185185185
# 결과 : 과체중
#
# 이름 : 자바
# 몸무게 : 44
# 키 : 195
# BMI : 11.571334648257725
# 결과 : 저체중
#
# 이름 : 가파
# 몸무게 : 98
# 키 : 169
# BMI : 34.31252407128602
# 결과 : 과체중
#
# 이름 : 카마
# 몸무게 : 94
# 키 : 162
# BMI : 35.81771071483005
# 결과 : 과체중
#
# 이름 : 나사
# 몸무게 : 71
# 키 : 186
# BMI : 20.522603769221874
# 결과 : 정상체중
#
# 이름 : 차카
# 몸무게 : 94
# 키 : 149
# BMI : 42.340435115535335
# 결과 : 과체중
#
# 이름 : 차마
# 몸무게 : 81
# 키 : 186
# BMI : 23.413111342351716
# 결과 : 정상체중
#
# 이름 : 라가
# 몸무게 : 77
# 키 : 144
# BMI : 37.13348765432099
# 결과 : 과체중
#
# 이름 : 가바
# 몸무게 : 43
# 키 : 186
# BMI : 12.429182564458317
# 결과 : 저체중
#
# 이름 : 가타
# 몸무게 : 43
# 키 : 154
# BMI : 18.13121942992073
# 결과 : 저체중
#
# 이름 : 하아
# 몸무게 : 66
# 키 : 165
# BMI : 24.242424242424246
# 결과 : 정상체중
#
# 이름 : 라가
# 몸무게 : 59
# 키 : 185
# BMI : 17.238860482103725
# 결과 : 저체중
#
# 이름 : 라라
# 몸무게 : 87
# 키 : 140
# BMI : 44.38775510204082
# 결과 : 과체중
#
# 이름 : 자차
# 몸무게 : 99
# 키 : 156
# BMI : 40.68047337278106
# 결과 : 과체중
#
# 이름 : 다나
# 몸무게 : 70
# 키 : 161
# BMI : 27.005130974885226
# 결과 : 과체중
#
# 이름 : 나라
# 몸무게 : 66
# 키 : 196
# BMI : 17.18034152436485
# 결과 : 저체중
#
# 이름 : 나다
# 몸무게 : 89
# 키 : 152
# BMI : 38.52146814404432
# 결과 : 과체중
#
# 이름 : 다파
# 몸무게 : 79
# 키 : 188
# BMI : 22.351742870076958
# 결과 : 정상체중
#
# 이름 : 카라
# 몸무게 : 47
# 키 : 185
# BMI : 13.732651570489407
# 결과 : 저체중
#
# 이름 : 사차
# 몸무게 : 54
# 키 : 160
# BMI : 21.093749999999996
# 결과 : 정상체중
#
# 이름 : 타파
# 몸무게 : 48
# 키 : 182
# BMI : 14.491003501992513
# 결과 : 저체중
#
# 이름 : 차사
# 몸무게 : 65
# 키 : 180
# BMI : 20.061728395061728
# 결과 : 정상체중
#
# 이름 : 아카
# 몸무게 : 79
# 키 : 194
# BMI : 20.990540971410354
# 결과 : 정상체중
#
# 이름 : 마차
# 몸무게 : 49
# 키 : 145
# BMI : 23.305588585017837
# 결과 : 정상체중
#
# 이름 : 사카
# 몸무게 : 95
# 키 : 163
# BMI : 35.75595618954421
# 결과 : 과체중
#
# 이름 : 하타
# 몸무게 : 67
# 키 : 143
# BMI : 32.76443835884396
# 결과 : 과체중
#
# 이름 : 타타
# 몸무게 : 90
# 키 : 192
# BMI : 24.4140625
# 결과 : 정상체중
#
# 이름 : 라아
# 몸무게 : 42
# 키 : 170
# BMI : 14.532871972318341
# 결과 : 저체중
#
# 이름 : 다파
# 몸무게 : 80
# 키 : 157
# BMI : 32.45567771512029
# 결과 : 과체중
#
# 이름 : 가하
# 몸무게 : 70
# 키 : 149
# BMI : 31.530111256249718
# 결과 : 과체중
#
# 이름 : 다아
# 몸무게 : 93
# 키 : 156
# BMI : 38.21499013806706
# 결과 : 과체중
#
# 이름 : 카라
# 몸무게 : 44
# 키 : 171
# BMI : 15.047365001196951
# 결과 : 저체중
#
# 이름 : 마자
# 몸무게 : 48
# 키 : 180
# BMI : 14.814814814814813
# 결과 : 저체중
#
# 이름 : 자가
# 몸무게 : 51
# 키 : 163
# BMI : 19.195302796492154
# 결과 : 정상체중
#
# 이름 : 파다
# 몸무게 : 59
# 키 : 151
# BMI : 25.876058067628612
# 결과 : 과체중
#
# 이름 : 라마
# 몸무게 : 61
# 키 : 157
# BMI : 24.747454257779218
# 결과 : 정상체중
#
# 이름 : 나라
# 몸무게 : 98
# 키 : 194
# BMI : 26.03889892655968
# 결과 : 과체중
#
# 이름 : 라라
# 몸무게 : 75
# 키 : 168
# BMI : 26.573129251700685
# 결과 : 과체중
#
# 이름 : 자바
# 몸무게 : 64
# 키 : 168
# BMI : 22.67573696145125
# 결과 : 정상체중
#
# 이름 : 자바
# 몸무게 : 72
# 키 : 169
# BMI : 25.209201358495854
# 결과 : 과체중
#
# 이름 : 차마
# 몸무게 : 45
# 키 : 150
# BMI : 20.0
# 결과 : 정상체중
#
# 이름 : 마가
# 몸무게 : 87
# 키 : 198
# BMI : 22.19161310070401
# 결과 : 정상체중
#
# 이름 : 하마
# 몸무게 : 59
# 키 : 144
# BMI : 28.452932098765434
# 결과 : 과체중
#
# 이름 : 자가
# 몸무게 : 62
# 키 : 169
# BMI : 21.707923392038097
# 결과 : 정상체중
#
# 이름 : 바마
# 몸무게 : 48
# 키 : 158
# BMI : 19.227687870533565
# 결과 : 정상체중
#
# 이름 : 바카
# 몸무게 : 59
# 키 : 196
# BMI : 15.358184089962517
# 결과 : 저체중
#
# 이름 : 하마
# 몸무게 : 50
# 키 : 193
# BMI : 13.423179145748879
# 결과 : 저체중
#
# 이름 : 나아
# 몸무게 : 51
# 키 : 191
# BMI : 13.979879937501714
# 결과 : 저체중
#
# 이름 : 라바
# 몸무게 : 56
# 키 : 178
# BMI : 17.67453604342886
# 결과 : 저체중
#
# 이름 : 가자
# 몸무게 : 53
# 키 : 153
# BMI : 22.64086462471699
# 결과 : 정상체중
#
# 이름 : 나타
# 몸무게 : 54
# 키 : 197
# BMI : 13.914298229792058
# 결과 : 저체중
#
# 이름 : 차나
# 몸무게 : 77
# 키 : 182
# BMI : 23.24598478444632
# 결과 : 정상체중
#
# 이름 : 마자
# 몸무게 : 66
# 키 : 142
# BMI : 32.73160087284269
# 결과 : 과체중
#
# 이름 : 라나
# 몸무게 : 47
# 키 : 176
# BMI : 15.173037190082646
# 결과 : 저체중
#
# 이름 : 마카
# 몸무게 : 50
# 키 : 180
# BMI : 15.432098765432098
# 결과 : 저체중
#
# 이름 : 나자
# 몸무게 : 61
# 키 : 144
# BMI : 29.41743827160494
# 결과 : 과체중
#
# 이름 : 사사
# 몸무게 : 87
# 키 : 141
# BMI : 43.760374226648565
# 결과 : 과체중
#
# 이름 : 타아
# 몸무게 : 96
# 키 : 159
# BMI : 37.97318144060757
# 결과 : 과체중
#
# 이름 : 마나
# 몸무게 : 96
# 키 : 145
# BMI : 45.65992865636147
# 결과 : 과체중
#
# 이름 : 카차
# 몸무게 : 56
# 키 : 165
# BMI : 20.569329660238754
# 결과 : 정상체중
#
# 이름 : 파가
# 몸무게 : 84
# 키 : 152
# BMI : 36.35734072022161
# 결과 : 과체중
#
# 이름 : 타다
# 몸무게 : 81
# 키 : 173
# BMI : 27.064051588760066
# 결과 : 과체중
#
# 이름 : 나아
# 몸무게 : 58
# 키 : 187
# BMI : 16.586119134090193
# 결과 : 저체중
#
# 이름 : 카차
# 몸무게 : 61
# 키 : 196
# BMI : 15.878800499791755
# 결과 : 저체중
#
# 이름 : 사파
# 몸무게 : 81
# 키 : 183
# BMI : 24.187046492878256
# 결과 : 정상체중
#
# 이름 : 나차
# 몸무게 : 92
# 키 : 170
# BMI : 31.83391003460208
# 결과 : 과체중
#
# 이름 : 가마
# 몸무게 : 71
# 키 : 173
# BMI : 23.722810651876106
# 결과 : 정상체중
#
# 이름 : 마자
# 몸무게 : 47
# 키 : 185
# BMI : 13.732651570489407
# 결과 : 저체중
#
# 이름 : 라사
# 몸무게 : 98
# 키 : 185
# BMI : 28.634039444850252
# 결과 : 과체중
#
# 이름 : 차라
# 몸무게 : 75
# 키 : 157
# BMI : 30.427197857925268
# 결과 : 과체중
#
# 이름 : 타마
# 몸무게 : 85
# 키 : 188
# BMI : 24.049343594386603
# 결과 : 정상체중
#
# 이름 : 라파
# 몸무게 : 52
# 키 : 185
# BMI : 15.193571950328705
# 결과 : 저체중
#
# 이름 : 자자
# 몸무게 : 40
# 키 : 158
# BMI : 16.023073225444637
# 결과 : 저체중
#
# 이름 : 자파
# 몸무게 : 84
# 키 : 155
# BMI : 34.96357960457856
# 결과 : 과체중
#
# 이름 : 파나
# 몸무게 : 52
# 키 : 152
# BMI : 22.506925207756233
# 결과 : 정상체중
#
# 이름 : 자마
# 몸무게 : 99
# 키 : 184
# BMI : 29.24149338374291
# 결과 : 과체중
#
# 이름 : 나다
# 몸무게 : 79
# 키 : 157
# BMI : 32.049981743681286
# 결과 : 과체중
#
# 이름 : 자바
# 몸무게 : 54
# 키 : 146
# BMI : 25.333083130043164
# 결과 : 과체중
#
# 이름 : 자마
# 몸무게 : 61
# 키 : 145
# BMI : 29.01307966706302
# 결과 : 과체중
#
# 이름 : 다아
# 몸무게 : 69
# 키 : 192
# BMI : 18.717447916666668
# 결과 : 정상체중
#
# 이름 : 라파
# 몸무게 : 95
# 키 : 170
# BMI : 32.871972318339104
# 결과 : 과체중
#
# 이름 : 자다
# 몸무게 : 64
# 키 : 170
# BMI : 22.145328719723185
# 결과 : 정상체중
#
# 이름 : 아바
# 몸무게 : 85
# 키 : 189
# BMI : 23.79552644102909
# 결과 : 정상체중
#
# 이름 : 다사
# 몸무게 : 88
# 키 : 192
# BMI : 23.87152777777778
# 결과 : 정상체중
#
# 이름 : 아라
# 몸무게 : 82
# 키 : 173
# BMI : 27.39817568244846
# 결과 : 과체중
#
# 이름 : 다다
# 몸무게 : 42
# 키 : 182
# BMI : 12.679628064243447
# 결과 : 저체중
#
# 이름 : 마하
# 몸무게 : 95
# 키 : 180
# BMI : 29.320987654320987
# 결과 : 과체중
#
# 이름 : 카하
# 몸무게 : 90
# 키 : 197
# BMI : 23.19049704965343
# 결과 : 정상체중
#
# 이름 : 아라
# 몸무게 : 76
# 키 : 173
# BMI : 25.393431120318084
# 결과 : 과체중
#
# 이름 : 파카
# 몸무게 : 61
# 키 : 170
# BMI : 21.107266435986162
# 결과 : 정상체중
#
# 이름 : 다바
# 몸무게 : 89
# 키 : 145
# BMI : 42.33055885850178
# 결과 : 과체중
#
# 이름 : 나가
# 몸무게 : 83
# 키 : 177
# BMI : 26.493025631204315
# 결과 : 과체중
#
# 이름 : 바사
# 몸무게 : 88
# 키 : 195
# BMI : 23.14266929651545
# 결과 : 정상체중
#
# 이름 : 가하
# 몸무게 : 65
# 키 : 168
# BMI : 23.030045351473927
# 결과 : 정상체중
#
# 이름 : 나마
# 몸무게 : 74
# 키 : 159
# BMI : 29.270994027135
# 결과 : 과체중
#
# 이름 : 나나
# 몸무게 : 79
# 키 : 167
# BMI : 28.326580372189753
# 결과 : 과체중
#
# 이름 : 타다
# 몸무게 : 43
# 키 : 147
# BMI : 19.899116109028647
# 결과 : 정상체중
#
# 이름 : 다파
# 몸무게 : 83
# 키 : 141
# BMI : 41.74840299783714
# 결과 : 과체중
#
# 이름 : 다카
# 몸무게 : 51
# 키 : 159
# BMI : 20.17325264032277
# 결과 : 정상체중
#
# 이름 : 카가
# 몸무게 : 81
# 키 : 158
# BMI : 32.446723281525394
# 결과 : 과체중
#
# 이름 : 하자
# 몸무게 : 76
# 키 : 192
# BMI : 20.616319444444446
# 결과 : 정상체중
#
# 이름 : 가마
# 몸무게 : 85
# 키 : 161
# BMI : 32.79194475521777
# 결과 : 과체중
#
# 이름 : 바마
# 몸무게 : 87
# 키 : 142
# BMI : 43.14620115056537
# 결과 : 과체중
#
# 이름 : 자바
# 몸무게 : 52
# 키 : 173
# BMI : 17.374452871796585
# 결과 : 저체중
#
# 이름 : 하하
# 몸무게 : 70
# 키 : 171
# BMI : 23.938989774631512
# 결과 : 정상체중
#
# 이름 : 바타
# 몸무게 : 58
# 키 : 174
# BMI : 19.157088122605362
# 결과 : 정상체중
#
# 이름 : 나카
# 몸무게 : 82
# 키 : 158
# BMI : 32.847300112161506
# 결과 : 과체중
#
# 이름 : 나라
# 몸무게 : 93
# 키 : 175
# BMI : 30.367346938775512
# 결과 : 과체중
#
# 이름 : 사차
# 몸무게 : 66
# 키 : 182
# BMI : 19.925129815239703
# 결과 : 정상체중
#
# 이름 : 라사
# 몸무게 : 57
# 키 : 180
# BMI : 17.59259259259259
# 결과 : 저체중
#
# 이름 : 차아
# 몸무게 : 60
# 키 : 180
# BMI : 18.51851851851852
# 결과 : 정상체중
#
# 이름 : 나자
# 몸무게 : 63
# 키 : 140
# BMI : 32.142857142857146
# 결과 : 과체중
#
# 이름 : 바타
# 몸무게 : 93
# 키 : 185
# BMI : 27.173119065010955
# 결과 : 과체중
#
# 이름 : 사카
# 몸무게 : 75
# 키 : 150
# BMI : 33.333333333333336
# 결과 : 과체중
#
# 이름 : 라라
# 몸무게 : 45
# 키 : 175
# BMI : 14.693877551020408
# 결과 : 저체중
#
# 이름 : 아타
# 몸무게 : 98
# 키 : 158
# BMI : 39.25652940233936
# 결과 : 과체중
#
# 이름 : 하차
# 몸무게 : 93
# 키 : 140
# BMI : 47.44897959183674
# 결과 : 과체중
#
# 이름 : 타아
# 몸무게 : 88
# 키 : 185
# BMI : 25.712198685171657
# 결과 : 과체중
#
# 이름 : 라카
# 몸무게 : 97
# 키 : 183
# BMI : 28.964734689002356
# 결과 : 과체중
#
# 이름 : 사다
# 몸무게 : 86
# 키 : 195
# BMI : 22.616699539776466
# 결과 : 정상체중
#
# 이름 : 마카
# 몸무게 : 48
# 키 : 180
# BMI : 14.814814814814813
# 결과 : 저체중
#
# 이름 : 마다
# 몸무게 : 40
# 키 : 186
# BMI : 11.562030292519365
# 결과 : 저체중
#
# 이름 : 바라
# 몸무게 : 48
# 키 : 191
# BMI : 13.157534058825142
# 결과 : 저체중
#
# 이름 : 타다
# 몸무게 : 65
# 키 : 193
# BMI : 17.450132889473544
# 결과 : 저체중
#
# 이름 : 다카
# 몸무게 : 46
# 키 : 156
# BMI : 18.902038132807363
# 결과 : 정상체중
#
# 이름 : 나나
# 몸무게 : 71
# 키 : 179
# BMI : 22.15910864205237
# 결과 : 정상체중
#
# 이름 : 라바
# 몸무게 : 99
# 키 : 162
# BMI : 37.722908093278456
# 결과 : 과체중
#
# 이름 : 다마
# 몸무게 : 72
# 키 : 153
# BMI : 30.757400999615534
# 결과 : 과체중
#
# 이름 : 아차
# 몸무게 : 79
# 키 : 195
# BMI : 20.77580539119001
# 결과 : 정상체중
#
# 이름 : 나마
# 몸무게 : 55
# 키 : 148
# BMI : 25.10956902848795
# 결과 : 과체중
#
# 이름 : 라차
# 몸무게 : 97
# 키 : 177
# BMI : 30.961728749720702
# 결과 : 과체중
#
# 이름 : 카라
# 몸무게 : 42
# 키 : 179
# BMI : 13.108205112199993
# 결과 : 저체중
#
# 이름 : 다타
# 몸무게 : 83
# 키 : 189
# BMI : 23.23563170124017
# 결과 : 정상체중
#
# 이름 : 차나
# 몸무게 : 45
# 키 : 155
# BMI : 18.730489073881373
# 결과 : 정상체중
#
# 이름 : 차바
# 몸무게 : 65
# 키 : 187
# BMI : 18.58789213303211
# 결과 : 정상체중
#
# 이름 : 라사
# 몸무게 : 80
# 키 : 148
# BMI : 36.52300949598247
# 결과 : 과체중
#
# 이름 : 하자
# 몸무게 : 97
# 키 : 151
# BMI : 42.54199377220297
# 결과 : 과체중
#
# 이름 : 사하
# 몸무게 : 80
# 키 : 186
# BMI : 23.12406058503873
# 결과 : 정상체중
#
# 이름 : 아라
# 몸무게 : 86
# 키 : 147
# BMI : 39.798232218057294
# 결과 : 과체중
#
# 이름 : 아바
# 몸무게 : 49
# 키 : 191
# BMI : 13.431649351717333
# 결과 : 저체중
#
# 이름 : 차자
# 몸무게 : 56
# 키 : 159
# BMI : 22.151022507021082
# 결과 : 정상체중
#
# 이름 : 사라
# 몸무게 : 94
# 키 : 169
# BMI : 32.91201288470292
# 결과 : 과체중
#
# 이름 : 차자
# 몸무게 : 71
# 키 : 199
# BMI : 17.928840180803515
# 결과 : 저체중
#
# 이름 : 카하
# 몸무게 : 92
# 키 : 185
# BMI : 26.880934989043094
# 결과 : 과체중
#
# 이름 : 자아
# 몸무게 : 62
# 키 : 155
# BMI : 25.806451612903224
# 결과 : 과체중
#
# 이름 : 나라
# 몸무게 : 62
# 키 : 194
# BMI : 16.473589116803062
# 결과 : 저체중
#
# 이름 : 파타
# 몸무게 : 94
# 키 : 141
# BMI : 47.281323877068566
# 결과 : 과체중
#
# 이름 : 차다
# 몸무게 : 98
# 키 : 159
# BMI : 38.764289387286894
# 결과 : 과체중
#
# 이름 : 나차
# 몸무게 : 52
# 키 : 171
# BMI : 17.783249546869126
# 결과 : 저체중
#
# 이름 : 타자
# 몸무게 : 47
# 키 : 157
# BMI : 19.067710657633167
# 결과 : 정상체중
#
# 이름 : 다파
# 몸무게 : 73
# 키 : 154
# BMI : 30.78090740428403
# 결과 : 과체중
#
# 이름 : 카파
# 몸무게 : 58
# 키 : 194
# BMI : 15.410776915718992
# 결과 : 저체중
#
# 이름 : 다다
# 몸무게 : 86
# 키 : 178
# BMI : 27.143037495265748
# 결과 : 과체중
#
# 이름 : 파마
# 몸무게 : 82
# 키 : 195
# BMI : 21.56476002629849
# 결과 : 정상체중
#
# 이름 : 마하
# 몸무게 : 60
# 키 : 172
# BMI : 20.281233098972418
# 결과 : 정상체중
#
# 이름 : 마하
# 몸무게 : 89
# 키 : 185
# BMI : 26.004382761139514
# 결과 : 과체중
#
# 이름 : 아타
# 몸무게 : 46
# 키 : 179
# BMI : 14.356605599076184
# 결과 : 저체중
#
# 이름 : 아파
# 몸무게 : 54
# 키 : 179
# BMI : 16.853406572828565
# 결과 : 저체중
#
# 이름 : 라차
# 몸무게 : 84
# 키 : 169
# BMI : 29.410734918245165
# 결과 : 과체중
#
# 이름 : 라바
# 몸무게 : 86
# 키 : 147
# BMI : 39.798232218057294
# 결과 : 과체중
#
# 이름 : 차라
# 몸무게 : 69
# 키 : 161
# BMI : 26.61934338952972
# 결과 : 과체중
#
# 이름 : 카다
# 몸무게 : 94
# 키 : 193
# BMI : 25.235576794007894
# 결과 : 과체중
#
# 이름 : 파가
# 몸무게 : 40
# 키 : 159
# BMI : 15.822158933586486
# 결과 : 저체중
#
# 이름 : 파차
# 몸무게 : 73
# 키 : 159
# BMI : 28.875440053795337
# 결과 : 과체중
#
# 이름 : 타바
# 몸무게 : 93
# 키 : 195
# BMI : 24.45759368836292
# 결과 : 정상체중
#
# 이름 : 하타
# 몸무게 : 92
# 키 : 160
# BMI : 35.93749999999999
# 결과 : 과체중
#
# 이름 : 다라
# 몸무게 : 88
# 키 : 148
# BMI : 40.17531044558072
# 결과 : 과체중
#
# 이름 : 타바
# 몸무게 : 55
# 키 : 162
# BMI : 20.957171162932475
# 결과 : 정상체중
#
# 이름 : 하라
# 몸무게 : 97
# 키 : 190
# BMI : 26.869806094182827
# 결과 : 과체중
#
# 이름 : 타아
# 몸무게 : 52
# 키 : 164
# BMI : 19.333729922665082
# 결과 : 정상체중
#
# 이름 : 차나
# 몸무게 : 99
# 키 : 160
# BMI : 38.67187499999999
# 결과 : 과체중
#
# 이름 : 아바
# 몸무게 : 99
# 키 : 199
# BMI : 24.999368702810536
# 결과 : 정상체중
#
# 이름 : 아파
# 몸무게 : 89
# 키 : 163
# BMI : 33.49768527230984
# 결과 : 과체중
#
# 이름 : 나카
# 몸무게 : 87
# 키 : 185
# BMI : 25.420014609203797
# 결과 : 과체중
#
# 이름 : 아다
# 몸무게 : 42
# 키 : 156
# BMI : 17.258382642998026
# 결과 : 저체중
#
# 이름 : 바타
# 몸무게 : 94
# 키 : 156
# BMI : 38.62590401051939
# 결과 : 과체중
#
# 이름 : 하파
# 몸무게 : 89
# 키 : 165
# BMI : 32.690541781450875
# 결과 : 과체중
#
# 이름 : 자사
# 몸무게 : 86
# 키 : 141
# BMI : 43.25738141944571
# 결과 : 과체중
#
# 이름 : 아파
# 몸무게 : 84
# 키 : 171
# BMI : 28.726787729557817
# 결과 : 과체중
#
# 이름 : 차카
# 몸무게 : 40
# 키 : 169
# BMI : 14.00511186583103
# 결과 : 저체중
#
# 이름 : 다사
# 몸무게 : 94
# 키 : 186
# BMI : 27.170771187420506
# 결과 : 과체중
#
# 이름 : 라차
# 몸무게 : 48
# 키 : 192
# BMI : 13.020833333333334
# 결과 : 저체중
#
# 이름 : 자다
# 몸무게 : 94
# 키 : 182
# BMI : 28.378215191402003
# 결과 : 과체중
#
# 이름 : 라라
# 몸무게 : 68
# 키 : 149
# BMI : 30.629250934642585
# 결과 : 과체중
#
# 이름 : 카아
# 몸무게 : 62
# 키 : 189
# BMI : 17.35673693345651
# 결과 : 저체중
#
# 이름 : 타사
# 몸무게 : 56
# 키 : 147
# BMI : 25.915127955944286
# 결과 : 과체중
#
# 이름 : 다가
# 몸무게 : 88
# 키 : 178
# BMI : 27.77427092538821
# 결과 : 과체중
#
# 이름 : 다라
# 몸무게 : 80
# 키 : 164
# BMI : 29.744199881023206
# 결과 : 과체중
#
# 이름 : 바마
# 몸무게 : 85
# 키 : 160
# BMI : 33.20312499999999
# 결과 : 과체중
#
# 이름 : 다타
# 몸무게 : 64
# 키 : 175
# BMI : 20.897959183673468
# 결과 : 정상체중
#
# 이름 : 나나
# 몸무게 : 45
# 키 : 156
# BMI : 18.49112426035503
# 결과 : 저체중
#
# 이름 : 차하
# 몸무게 : 91
# 키 : 155
# BMI : 37.87721123829344
# 결과 : 과체중
#
# 이름 : 하카
# 몸무게 : 53
# 키 : 169
# BMI : 18.556773222226116
# 결과 : 정상체중
#
# 이름 : 라사
# 몸무게 : 61
# 키 : 193
# BMI : 16.376278557813635
# 결과 : 저체중
#
# 이름 : 카자
# 몸무게 : 40
# 키 : 146
# BMI : 18.765246762994934
# 결과 : 정상체중
#
# 이름 : 마사
# 몸무게 : 98
# 키 : 174
# BMI : 32.368873034747
# 결과 : 과체중
#
# 이름 : 다사
# 몸무게 : 88
# 키 : 151
# BMI : 38.59479847375115
# 결과 : 과체중
#
# 이름 : 다아
# 몸무게 : 58
# 키 : 185
# BMI : 16.946676406135865
# 결과 : 저체중
#
# 이름 : 아하
# 몸무게 : 42
# 키 : 157
# BMI : 17.03923080043815
# 결과 : 저체중
#
# 이름 : 다타
# 몸무게 : 51
# 키 : 189
# BMI : 14.277315864617453
# 결과 : 저체중
#
# 이름 : 하차
# 몸무게 : 79
# 키 : 183
# BMI : 23.589835468362743
# 결과 : 정상체중
#
# 이름 : 마다
# 몸무게 : 91
# 키 : 169
# BMI : 31.861629494765594
# 결과 : 과체중
#
# 이름 : 나가
# 몸무게 : 82
# 키 : 161
# BMI : 31.634581999151262
# 결과 : 과체중
#
# 이름 : 자아
# 몸무게 : 91
# 키 : 163
# BMI : 34.25044224472129
# 결과 : 과체중
#
# 이름 : 파하
# 몸무게 : 83
# 키 : 183
# BMI : 24.78425751739377
# 결과 : 정상체중
#
# 이름 : 사파
# 몸무게 : 63
# 키 : 168
# BMI : 22.321428571428577
# 결과 : 정상체중
#
# 이름 : 파타
# 몸무게 : 81
# 키 : 152
# BMI : 35.05886426592798
# 결과 : 과체중
#
# 이름 : 차라
# 몸무게 : 46
# 키 : 173
# BMI : 15.36970830966621
# 결과 : 저체중
#
# 이름 : 마하
# 몸무게 : 57
# 키 : 152
# BMI : 24.67105263157895
# 결과 : 정상체중
#
# 이름 : 다아
# 몸무게 : 41
# 키 : 179
# BMI : 12.796104990480947
# 결과 : 저체중
#
# 이름 : 라하
# 몸무게 : 58
# 키 : 183
# BMI : 17.319119710949863
# 결과 : 저체중
#
# 이름 : 마파
# 몸무게 : 85
# 키 : 156
# BMI : 34.927679158448385
# 결과 : 과체중
#
# 이름 : 자사
# 몸무게 : 63
# 키 : 162
# BMI : 24.005486968449926
# 결과 : 정상체중
#
# 이름 : 라하
# 몸무게 : 75
# 키 : 169
# BMI : 26.25958474843318
# 결과 : 과체중
#
# 이름 : 자타
# 몸무게 : 45
# 키 : 196
# BMI : 11.713869221157852
# 결과 : 저체중
#
# 이름 : 타라
# 몸무게 : 88
# 키 : 165
# BMI : 32.323232323232325
# 결과 : 과체중
#
# 이름 : 가파
# 몸무게 : 47
# 키 : 189
# BMI : 13.157526385039613
# 결과 : 저체중
#
# 이름 : 차파
# 몸무게 : 79
# 키 : 197
# BMI : 20.3561029658069
# 결과 : 정상체중
#
# 이름 : 파파
# 몸무게 : 54
# 키 : 159
# BMI : 21.359914560341757
# 결과 : 정상체중
#
# 이름 : 카아
# 몸무게 : 94
# 키 : 181
# BMI : 28.692652849424622
# 결과 : 과체중
#
# 이름 : 사아
# 몸무게 : 84
# 키 : 169
# BMI : 29.410734918245165
# 결과 : 과체중
#
# 이름 : 가자
# 몸무게 : 78
# 키 : 173
# BMI : 26.061679307694877
# 결과 : 과체중
#
# 이름 : 바파
# 몸무게 : 89
# 키 : 180
# BMI : 27.469135802469133
# 결과 : 과체중
#
# 이름 : 카다
# 몸무게 : 68
# 키 : 150
# BMI : 30.22222222222222
# 결과 : 과체중
#
# 이름 : 차파
# 몸무게 : 88
# 키 : 144
# BMI : 42.43827160493827
# 결과 : 과체중
#
# 이름 : 아차
# 몸무게 : 84
# 키 : 153
# BMI : 35.883634499551455
# 결과 : 과체중
#
# 이름 : 타가
# 몸무게 : 63
# 키 : 184
# BMI : 18.608223062381853
# 결과 : 정상체중
#
# 이름 : 마카
# 몸무게 : 55
# 키 : 190
# BMI : 15.235457063711912
# 결과 : 저체중
#
# 이름 : 파라
# 몸무게 : 68
# 키 : 158
# BMI : 27.239224483255885
# 결과 : 과체중
#
# 이름 : 다차
# 몸무게 : 96
# 키 : 188
# BMI : 27.16161158895428
# 결과 : 과체중
#
# 이름 : 카나
# 몸무게 : 89
# 키 : 174
# BMI : 29.396221429515126
# 결과 : 과체중
#
# 이름 : 타사
# 몸무게 : 41
# 키 : 152
# BMI : 17.74584487534626
# 결과 : 저체중
#
# 이름 : 마바
# 몸무게 : 66
# 키 : 170
# BMI : 22.837370242214536
# 결과 : 정상체중
#
# 이름 : 차다
# 몸무게 : 43
# 키 : 144
# BMI : 20.736882716049383
# 결과 : 정상체중
#
# 이름 : 타타
# 몸무게 : 47
# 키 : 191
# BMI : 12.883418765932952
# 결과 : 저체중
#
# 이름 : 가타
# 몸무게 : 78
# 키 : 170
# BMI : 26.989619377162633
# 결과 : 과체중
#
# 이름 : 라타
# 몸무게 : 75
# 키 : 183
# BMI : 22.395413419331717
# 결과 : 정상체중
#
# 이름 : 마하
# 몸무게 : 92
# 키 : 141
# BMI : 46.27533826266285
# 결과 : 과체중
#
# 이름 : 다라
# 몸무게 : 67
# 키 : 176
# BMI : 21.62964876033058
# 결과 : 정상체중
#
# 이름 : 라마
# 몸무게 : 54
# 키 : 168
# BMI : 19.13265306122449
# 결과 : 정상체중
#
# 이름 : 사파
# 몸무게 : 94
# 키 : 146
# BMI : 44.0983298930381
# 결과 : 과체중
#
# 이름 : 차파
# 몸무게 : 83
# 키 : 154
# BMI : 34.99747006240513
# 결과 : 과체중
#
# 이름 : 가자
# 몸무게 : 62
# 키 : 174
# BMI : 20.478266613819528
# 결과 : 정상체중
#
# 이름 : 마마
# 몸무게 : 94
# 키 : 149
# BMI : 42.340435115535335
# 결과 : 과체중
#
# 이름 : 가차
# 몸무게 : 53
# 키 : 178
# BMI : 16.72768589824517
# 결과 : 저체중
#
# 이름 : 아다
# 몸무게 : 68
# 키 : 140
# BMI : 34.693877551020414
# 결과 : 과체중
#
# 이름 : 카마
# 몸무게 : 69
# 키 : 164
# BMI : 25.654372397382513
# 결과 : 과체중
#
# 이름 : 파파
# 몸무게 : 48
# 키 : 171
# BMI : 16.415307274033037
# 결과 : 저체중
#
# 이름 : 바나
# 몸무게 : 81
# 키 : 183
# BMI : 24.187046492878256
# 결과 : 정상체중
#
# 이름 : 바가
# 몸무게 : 51
# 키 : 188
# BMI : 14.42960615663196
# 결과 : 저체중
#
# 이름 : 파타
# 몸무게 : 73
# 키 : 167
# BMI : 26.175194521137367
# 결과 : 과체중
#
# 이름 : 다카
# 몸무게 : 42
# 키 : 162
# BMI : 16.00365797896662
# 결과 : 저체중
#
# 이름 : 자차
# 몸무게 : 76
# 키 : 168
# BMI : 26.92743764172336
# 결과 : 과체중
#
# 이름 : 바타
# 몸무게 : 68
# 키 : 163
# BMI : 25.59373706198954
# 결과 : 과체중
#
# 이름 : 아카
# 몸무게 : 95
# 키 : 143
# BMI : 46.457039464032476
# 결과 : 과체중
#
# 이름 : 바타
# 몸무게 : 63
# 키 : 195
# BMI : 16.568047337278106
# 결과 : 저체중
#
# 이름 : 바파
# 몸무게 : 96
# 키 : 157
# BMI : 38.946813258144346
# 결과 : 과체중
#
# 이름 : 마사
# 몸무게 : 55
# 키 : 160
# BMI : 21.484374999999996
# 결과 : 정상체중
#
# 이름 : 하하
# 몸무게 : 66
# 키 : 146
# BMI : 30.962657158941646
# 결과 : 과체중
#
# 이름 : 라카
# 몸무게 : 59
# 키 : 174
# BMI : 19.487382745408905
# 결과 : 정상체중
#
# 이름 : 마사
# 몸무게 : 85
# 키 : 179
# BMI : 26.528510346119035
# 결과 : 과체중
#
# 이름 : 차마
# 몸무게 : 55
# 키 : 188
# BMI : 15.56133997283839
# 결과 : 저체중
#
# 이름 : 나하
# 몸무게 : 71
# 키 : 160
# BMI : 27.734374999999993
# 결과 : 과체중
#
# 이름 : 나카
# 몸무게 : 56
# 키 : 171
# BMI : 19.15119181970521
# 결과 : 정상체중
#
# 이름 : 아마
# 몸무게 : 51
# 키 : 172
# BMI : 17.239048134126556
# 결과 : 저체중
#
# 이름 : 마하
# 몸무게 : 59
# 키 : 149
# BMI : 26.575379487410476
# 결과 : 과체중
#
# 이름 : 카다
# 몸무게 : 42
# 키 : 174
# BMI : 13.87237415774871
# 결과 : 저체중
#
# 이름 : 바차
# 몸무게 : 55
# 키 : 188
# BMI : 15.56133997283839
# 결과 : 저체중
#
# 이름 : 카아
# 몸무게 : 72
# 키 : 187
# BMI : 20.58966513197403
# 결과 : 정상체중
#
# 이름 : 카차
# 몸무게 : 73
# 키 : 141
# BMI : 36.718474925808565
# 결과 : 과체중
#
# 이름 : 마파
# 몸무게 : 84
# 키 : 147
# BMI : 38.87269193391643
# 결과 : 과체중
#
# 이름 : 다나
# 몸무게 : 89
# 키 : 144
# BMI : 42.920524691358025
# 결과 : 과체중
#
# 이름 : 자사
# 몸무게 : 58
# 키 : 181
# BMI : 17.70397729007051
# 결과 : 저체중
#
# 이름 : 차다
# 몸무게 : 40
# 키 : 198
# BMI : 10.20304050607081
# 결과 : 저체중
#
# 이름 : 다차
# 몸무게 : 99
# 키 : 149
# BMI : 44.59258591955317
# 결과 : 과체중
#
# 이름 : 바사
# 몸무게 : 96
# 키 : 187
# BMI : 27.45288684263204
# 결과 : 과체중
#
# 이름 : 마하
# 몸무게 : 84
# 키 : 140
# BMI : 42.85714285714286
# 결과 : 과체중
#
# 이름 : 마라
# 몸무게 : 81
# 키 : 185
# BMI : 23.66691015339664
# 결과 : 정상체중
#
# 이름 : 타가
# 몸무게 : 89
# 키 : 153
# BMI : 38.01956512452475
# 결과 : 과체중
#
# 이름 : 타라
# 몸무게 : 42
# 키 : 186
# BMI : 12.140131807145334
# 결과 : 저체중
#
# 이름 : 카차
# 몸무게 : 54
# 키 : 163
# BMI : 20.32443825510934
# 결과 : 정상체중
#
# 이름 : 라카
# 몸무게 : 56
# 키 : 184
# BMI : 16.5406427221172
# 결과 : 저체중
#
# 이름 : 타가
# 몸무게 : 95
# 키 : 195
# BMI : 24.983563445101908
# 결과 : 정상체중
#
# 이름 : 라하
# 몸무게 : 67
# 키 : 182
# BMI : 20.227025721531216
# 결과 : 정상체중
#
# 이름 : 마하
# 몸무게 : 41
# 키 : 177
# BMI : 13.086916275655144
# 결과 : 저체중
#
# 이름 : 아사
# 몸무게 : 80
# 키 : 141
# BMI : 40.239424576228565
# 결과 : 과체중
#
# 이름 : 파하
# 몸무게 : 53
# 키 : 190
# BMI : 14.681440443213297
# 결과 : 저체중
#
# 이름 : 파차
# 몸무게 : 73
# 키 : 155
# BMI : 30.38501560874089
# 결과 : 과체중
#
# 이름 : 자카
# 몸무게 : 99
# 키 : 194
# BMI : 26.304601976830696
# 결과 : 과체중
#
# 이름 : 아바
# 몸무게 : 60
# 키 : 154
# BMI : 25.2993759487266
# 결과 : 과체중
#
# 이름 : 나나
# 몸무게 : 55
# 키 : 179
# BMI : 17.165506694547613
# 결과 : 저체중
#
# 이름 : 사마
# 몸무게 : 91
# 키 : 157
# BMI : 36.91833340094933
# 결과 : 과체중
#
# 이름 : 차카
# 몸무게 : 96
# 키 : 155
# BMI : 39.95837669094693
# 결과 : 과체중
#
# 이름 : 사타
# 몸무게 : 66
# 키 : 184
# BMI : 19.494328922495274
# 결과 : 정상체중
#
# 이름 : 타자
# 몸무게 : 97
# 키 : 181
# BMI : 29.60837581270413
# 결과 : 과체중
#
# 이름 : 타파
# 몸무게 : 46
# 키 : 197
# BMI : 11.85292071426731
# 결과 : 저체중
#
# 이름 : 나나
# 몸무게 : 58
# 키 : 187
# BMI : 16.586119134090193
# 결과 : 저체중
#
# 이름 : 차자
# 몸무게 : 94
# 키 : 155
# BMI : 39.12591050988553
# 결과 : 과체중
#
# 이름 : 다하
# 몸무게 : 73
# 키 : 190
# BMI : 20.221606648199447
# 결과 : 정상체중

# %%
# 이진 파일 처리 -b

data = ""

with open("c:/windows/notepad.exe","rb") as f1:
    data = f1.read()
    
with open("c:/temp/notepad.exe","wb") as f2:
    f2.write(data)
